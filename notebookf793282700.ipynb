# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# !git clone https://github.com/alibabasglab/MossFormer2.git
# %cd MossFormer2
# !ls
# !find . -maxdepth 2 -type d | sort
# !find MossFormer2_standalone -maxdepth 2 -type f | sort
# !find MossFormer2_samples_Libri2Mix -maxdepth 2 -type f | sort

# !pip install -r MossFormer2_standalone/requirements.txt
# !cat MossFormer2_standalone/requirements.txt
# !head -120 MossFormer2_standalone/inference.py
# !head -120 MossFormer2_standalone/model/mossformer2.py
# !pip install torchmetrics
# Out:
# Cloning into 'MossFormer2'...
# remote: Enumerating objects: 1020, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 1020 (delta 9), reused 23 (delta 1), pack-reused 982 (from 1)
# Receiving objects: 100% (1020/1020), 60.86 MiB | 32.44 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /kaggle/working/MossFormer2/MossFormer2/MossFormer2/MossFormer2
# LICENSE			       MossFormer2_samples_WSJ0-2mix
# MossFormer2_samples_Libri2Mix  MossFormer2_samples_WSJ0-3mix
# MossFormer2_samples_WHAM       MossFormer2_standalone
# MossFormer2_samples_WHAMR      README.md
# .
# ./.git
# ./.git/branches
# ./.git/hooks
# ./.git/info
# ./.git/logs
# ./.git/objects
# ./.git/refs
# ./MossFormer2_samples_Libri2Mix
# ./MossFormer2_samples_WHAM
# ./MossFormer2_samples_WHAMR
# ./MossFormer2_samples_WSJ0-2mix
# ./MossFormer2_samples_WSJ0-3mix
# ./MossFormer2_standalone
# ./MossFormer2_standalone/model
# ./MossFormer2_standalone/test_samples
# MossFormer2_standalone/inference.py
# MossFormer2_standalone/model/__init__.py
# MossFormer2_standalone/model/mossformer2_configs.py
# MossFormer2_standalone/model/mossformer2.py
# MossFormer2_standalone/README.md
# MossFormer2_standalone/requirements.txt
# MossFormer2_samples_Libri2Mix/item0_mix.wav
# MossFormer2_samples_Libri2Mix/item0_source1hat.wav
# MossFormer2_samples_Libri2Mix/item0_source1.wav
# MossFormer2_samples_Libri2Mix/item0_source2hat.wav
# MossFormer2_samples_Libri2Mix/item0_source2.wav
# MossFormer2_samples_Libri2Mix/item10_mix.wav
# MossFormer2_samples_Libri2Mix/item10_source1hat.wav
# MossFormer2_samples_Libri2Mix/item10_source1.wav
# MossFormer2_samples_Libri2Mix/item10_source2hat.wav
# MossFormer2_samples_Libri2Mix/item10_source2.wav
# MossFormer2_samples_Libri2Mix/item11_mix.wav
# MossFormer2_samples_Libri2Mix/item11_source1hat.wav
# MossFormer2_samples_Libri2Mix/item11_source1.wav
# MossFormer2_samples_Libri2Mix/item11_source2hat.wav
# MossFormer2_samples_Libri2Mix/item11_source2.wav
# MossFormer2_samples_Libri2Mix/item12_mix.wav
# MossFormer2_samples_Libri2Mix/item12_source1hat.wav
# MossFormer2_samples_Libri2Mix/item12_source1.wav
# MossFormer2_samples_Libri2Mix/item12_source2hat.wav
# MossFormer2_samples_Libri2Mix/item12_source2.wav
# MossFormer2_samples_Libri2Mix/item13_mix.wav
# MossFormer2_samples_Libri2Mix/item13_source1hat.wav
# MossFormer2_samples_Libri2Mix/item13_source1.wav
# MossFormer2_samples_Libri2Mix/item13_source2hat.wav
# MossFormer2_samples_Libri2Mix/item13_source2.wav
# MossFormer2_samples_Libri2Mix/item14_mix.wav
# MossFormer2_samples_Libri2Mix/item14_source1hat.wav
# MossFormer2_samples_Libri2Mix/item14_source1.wav
# MossFormer2_samples_Libri2Mix/item14_source2hat.wav
# MossFormer2_samples_Libri2Mix/item14_source2.wav
# MossFormer2_samples_Libri2Mix/item15_mix.wav
# MossFormer2_samples_Libri2Mix/item15_source1hat.wav
# MossFormer2_samples_Libri2Mix/item15_source1.wav
# MossFormer2_samples_Libri2Mix/item15_source2hat.wav
# MossFormer2_samples_Libri2Mix/item15_source2.wav
# MossFormer2_samples_Libri2Mix/item16_mix.wav
# MossFormer2_samples_Libri2Mix/item16_source1hat.wav
# MossFormer2_samples_Libri2Mix/item16_source1.wav
# MossFormer2_samples_Libri2Mix/item16_source2hat.wav
# MossFormer2_samples_Libri2Mix/item16_source2.wav
# MossFormer2_samples_Libri2Mix/item17_mix.wav
# MossFormer2_samples_Libri2Mix/item17_source1hat.wav
# MossFormer2_samples_Libri2Mix/item17_source1.wav
# MossFormer2_samples_Libri2Mix/item17_source2hat.wav
# MossFormer2_samples_Libri2Mix/item17_source2.wav
# MossFormer2_samples_Libri2Mix/item18_mix.wav
# MossFormer2_samples_Libri2Mix/item18_source1hat.wav
# MossFormer2_samples_Libri2Mix/item18_source1.wav
# MossFormer2_samples_Libri2Mix/item18_source2hat.wav
# MossFormer2_samples_Libri2Mix/item18_source2.wav
# MossFormer2_samples_Libri2Mix/item19_mix.wav
# MossFormer2_samples_Libri2Mix/item19_source1hat.wav
# MossFormer2_samples_Libri2Mix/item19_source1.wav
# MossFormer2_samples_Libri2Mix/item19_source2hat.wav
# MossFormer2_samples_Libri2Mix/item19_source2.wav
# MossFormer2_samples_Libri2Mix/item1_mix.wav
# MossFormer2_samples_Libri2Mix/item1_source1hat.wav
# MossFormer2_samples_Libri2Mix/item1_source1.wav
# MossFormer2_samples_Libri2Mix/item1_source2hat.wav
# MossFormer2_samples_Libri2Mix/item1_source2.wav
# MossFormer2_samples_Libri2Mix/item20_mix.wav
# MossFormer2_samples_Libri2Mix/item20_source1hat.wav
# MossFormer2_samples_Libri2Mix/item20_source1.wav
# MossFormer2_samples_Libri2Mix/item20_source2hat.wav
# MossFormer2_samples_Libri2Mix/item20_source2.wav
# MossFormer2_samples_Libri2Mix/item21_mix.wav
# MossFormer2_samples_Libri2Mix/item21_source1hat.wav
# MossFormer2_samples_Libri2Mix/item21_source1.wav
# MossFormer2_samples_Libri2Mix/item21_source2hat.wav
# MossFormer2_samples_Libri2Mix/item21_source2.wav
# MossFormer2_samples_Libri2Mix/item22_mix.wav
# MossFormer2_samples_Libri2Mix/item22_source1hat.wav
# MossFormer2_samples_Libri2Mix/item22_source1.wav
# MossFormer2_samples_Libri2Mix/item22_source2hat.wav
# MossFormer2_samples_Libri2Mix/item22_source2.wav
# MossFormer2_samples_Libri2Mix/item23_mix.wav
# MossFormer2_samples_Libri2Mix/item23_source1hat.wav
# MossFormer2_samples_Libri2Mix/item23_source1.wav
# MossFormer2_samples_Libri2Mix/item23_source2hat.wav
# MossFormer2_samples_Libri2Mix/item23_source2.wav
# MossFormer2_samples_Libri2Mix/item24_mix.wav
# MossFormer2_samples_Libri2Mix/item24_source1hat.wav
# MossFormer2_samples_Libri2Mix/item24_source1.wav
# MossFormer2_samples_Libri2Mix/item24_source2hat.wav
# MossFormer2_samples_Libri2Mix/item24_source2.wav
# MossFormer2_samples_Libri2Mix/item25_mix.wav
# MossFormer2_samples_Libri2Mix/item25_source1hat.wav
# MossFormer2_samples_Libri2Mix/item25_source1.wav
# MossFormer2_samples_Libri2Mix/item25_source2hat.wav
# MossFormer2_samples_Libri2Mix/item25_source2.wav
# MossFormer2_samples_Libri2Mix/item26_mix.wav
# MossFormer2_samples_Libri2Mix/item26_source1hat.wav
# MossFormer2_samples_Libri2Mix/item26_source1.wav
# MossFormer2_samples_Libri2Mix/item26_source2hat.wav
# MossFormer2_samples_Libri2Mix/item26_source2.wav
# MossFormer2_samples_Libri2Mix/item27_mix.wav
# MossFormer2_samples_Libri2Mix/item27_source1hat.wav
# MossFormer2_samples_Libri2Mix/item27_source1.wav
# MossFormer2_samples_Libri2Mix/item27_source2hat.wav
# MossFormer2_samples_Libri2Mix/item27_source2.wav
# MossFormer2_samples_Libri2Mix/item28_mix.wav
# MossFormer2_samples_Libri2Mix/item28_source1hat.wav
# MossFormer2_samples_Libri2Mix/item28_source1.wav
# MossFormer2_samples_Libri2Mix/item28_source2hat.wav
# MossFormer2_samples_Libri2Mix/item28_source2.wav
# MossFormer2_samples_Libri2Mix/item29_mix.wav
# MossFormer2_samples_Libri2Mix/item29_source1hat.wav
# MossFormer2_samples_Libri2Mix/item29_source1.wav
# MossFormer2_samples_Libri2Mix/item29_source2hat.wav
# MossFormer2_samples_Libri2Mix/item29_source2.wav
# MossFormer2_samples_Libri2Mix/item2_mix.wav
# MossFormer2_samples_Libri2Mix/item2_source1hat.wav
# MossFormer2_samples_Libri2Mix/item2_source1.wav
# MossFormer2_samples_Libri2Mix/item2_source2hat.wav
# MossFormer2_samples_Libri2Mix/item2_source2.wav
# MossFormer2_samples_Libri2Mix/item30_mix.wav
# MossFormer2_samples_Libri2Mix/item30_source1hat.wav
# MossFormer2_samples_Libri2Mix/item30_source1.wav
# MossFormer2_samples_Libri2Mix/item30_source2hat.wav
# MossFormer2_samples_Libri2Mix/item30_source2.wav
# MossFormer2_samples_Libri2Mix/item31_mix.wav
# MossFormer2_samples_Libri2Mix/item31_source1hat.wav
# MossFormer2_samples_Libri2Mix/item31_source1.wav
# MossFormer2_samples_Libri2Mix/item31_source2hat.wav
# MossFormer2_samples_Libri2Mix/item31_source2.wav
# MossFormer2_samples_Libri2Mix/item32_mix.wav
# MossFormer2_samples_Libri2Mix/item32_source1hat.wav
# MossFormer2_samples_Libri2Mix/item32_source1.wav
# MossFormer2_samples_Libri2Mix/item32_source2hat.wav
# MossFormer2_samples_Libri2Mix/item32_source2.wav
# MossFormer2_samples_Libri2Mix/item33_mix.wav
# MossFormer2_samples_Libri2Mix/item33_source1hat.wav
# MossFormer2_samples_Libri2Mix/item33_source1.wav
# MossFormer2_samples_Libri2Mix/item33_source2hat.wav
# MossFormer2_samples_Libri2Mix/item33_source2.wav
# MossFormer2_samples_Libri2Mix/item34_mix.wav
# MossFormer2_samples_Libri2Mix/item34_source1hat.wav
# MossFormer2_samples_Libri2Mix/item34_source1.wav
# MossFormer2_samples_Libri2Mix/item34_source2hat.wav
# MossFormer2_samples_Libri2Mix/item34_source2.wav
# MossFormer2_samples_Libri2Mix/item35_mix.wav
# MossFormer2_samples_Libri2Mix/item35_source1hat.wav
# MossFormer2_samples_Libri2Mix/item35_source1.wav
# MossFormer2_samples_Libri2Mix/item35_source2hat.wav
# MossFormer2_samples_Libri2Mix/item35_source2.wav
# MossFormer2_samples_Libri2Mix/item3_mix.wav
# MossFormer2_samples_Libri2Mix/item3_source1hat.wav
# MossFormer2_samples_Libri2Mix/item3_source1.wav
# MossFormer2_samples_Libri2Mix/item3_source2hat.wav
# MossFormer2_samples_Libri2Mix/item3_source2.wav
# MossFormer2_samples_Libri2Mix/item4_mix.wav
# MossFormer2_samples_Libri2Mix/item4_source1hat.wav
# MossFormer2_samples_Libri2Mix/item4_source1.wav
# MossFormer2_samples_Libri2Mix/item4_source2hat.wav
# MossFormer2_samples_Libri2Mix/item4_source2.wav
# MossFormer2_samples_Libri2Mix/item5_mix.wav
# MossFormer2_samples_Libri2Mix/item5_source1hat.wav
# MossFormer2_samples_Libri2Mix/item5_source1.wav
# MossFormer2_samples_Libri2Mix/item5_source2hat.wav
# MossFormer2_samples_Libri2Mix/item5_source2.wav
# MossFormer2_samples_Libri2Mix/item6_mix.wav
# MossFormer2_samples_Libri2Mix/item6_source1hat.wav
# MossFormer2_samples_Libri2Mix/item6_source1.wav
# MossFormer2_samples_Libri2Mix/item6_source2hat.wav
# MossFormer2_samples_Libri2Mix/item6_source2.wav
# MossFormer2_samples_Libri2Mix/item7_mix.wav
# MossFormer2_samples_Libri2Mix/item7_source1hat.wav
# MossFormer2_samples_Libri2Mix/item7_source1.wav
# MossFormer2_samples_Libri2Mix/item7_source2hat.wav
# MossFormer2_samples_Libri2Mix/item7_source2.wav
# MossFormer2_samples_Libri2Mix/item8_mix.wav
# MossFormer2_samples_Libri2Mix/item8_source1hat.wav
# MossFormer2_samples_Libri2Mix/item8_source1.wav
# MossFormer2_samples_Libri2Mix/item8_source2hat.wav
# MossFormer2_samples_Libri2Mix/item8_source2.wav
# MossFormer2_samples_Libri2Mix/item9_mix.wav
# MossFormer2_samples_Libri2Mix/item9_source1hat.wav
# MossFormer2_samples_Libri2Mix/item9_source1.wav
# MossFormer2_samples_Libri2Mix/item9_source2hat.wav
# MossFormer2_samples_Libri2Mix/item9_source2.wav
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r MossFormer2_standalone/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r MossFormer2_standalone/requirements.txt (line 2)) (2.10.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r MossFormer2_standalone/requirements.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r MossFormer2_standalone/requirements.txt (line 4)) (1.11.0)
# Requirement already satisfied: rotary_embedding_torch in /usr/local/lib/python3.12/dist-packages (from -r MossFormer2_standalone/requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r MossFormer2_standalone/requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (0.24.2)
# Requirement already satisfied: einops>=0.8 in /usr/local/lib/python3.12/dist-packages (from rotary_embedding_torch->-r MossFormer2_standalone/requirements.txt (line 5)) (0.8.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r MossFormer2_standalone/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r MossFormer2_standalone/requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->-r MossFormer2_standalone/requirements.txt (line 4)) (0.1.2)
# numpy
# torch
# torchaudio
# huggingface_hub
# rotary_embedding_torch
# '''This is a sample inference script to demonstrate how to run inference on the model for a single .wav file
#
# Authors
# * Jia Qi Yip 2024
# '''
# import torch
# from model.mossformer2 import Mossformer2Wrapper
#
# model_configs = ["mossformer2-librimix-2spk", "mossformer2-wsj0mix-3spk", "mossformer2-whamr-2spk"]
#
# for mc in model_configs:
#     model = Mossformer2Wrapper.from_pretrained(f'alibabasglab/{mc}')
#     model.inference(f'./test_samples/{mc}/item0_mix.wav',f'./test_samples/{mc}/model_output')'''Library to support Mossformer2
#
# Authors
# * Shengkui Zhao 2024
# * Jia Qi Yip 2024
# '''
# import os
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torchaudio
# from huggingface_hub import PyTorchModelHubMixin
#
# from .utils.one_path_flash_fsmn import Encoder, Decoder, Dual_Path_Model, SBFLASHBlock_DualA
#
# def getCheckpoints(config_name):
#
#     from huggingface_hub import hf_hub_download
#
#     for file in ['encoder','decoder','masknet']:
#         if not os.path.exists(f'./model_weights/{config_name}/{file}.ckpt'):
#             print(f'downloading {file}.cpkt')
#             hf_hub_download(repo_id=f'alibabasglab/{config_name}', filename=f'{file}.ckpt', local_dir=f'./model_weights/{config_name}')
#             print(f'{file}.cpkt downloaded')
#         else:
#             print(f'{file}.cpkt already downloaded')
#
# class Mossformer2Wrapper(nn.Module, PyTorchModelHubMixin):
#     """The wrapper for the Mossformer2 model which combines the Encoder, Masknet and the Encoder
#     https://arxiv.org/pdf/2312.11825v1.pdf
#
#     Example
#     -----
#     >>> model = Mossformer2Wrapper(config)
#     >>> inp = torch.rand(1, 160)
#     >>> result = model.forward(inp)
#     >>> result.shape
#     torch.Size([1, 160, 2])
#     """
#
#     def __init__(
#         self,
#         config: dict
#     ):
#
#         super(Mossformer2Wrapper, self).__init__()
#
#         self.config_name = config["config_name"]
#         print(f'{self.config_name} config loaded')
#
#         self.encoder = Encoder(
#             kernel_size=config['encoder_kernel_size'],
#             out_channels=config['encoder_out_nchannels'],
#             in_channels=config['encoder_in_nchannels'],
#         )
#
#         intra_model = SBFLASHBlock_DualA(
#             num_layers=config['intra_numlayers'],
#             d_model=config['encoder_out_nchannels'],
#             nhead=config['intra_nhead'],
#             d_ffn=config['intra_dffn'],
#             dropout=config['intra_dropout'],
#             use_positional_encoding=config['intra_use_positional'],
#             norm_before=config['intra_norm_before'],
#         )
#
#         self.masknet = Dual_Path_Model(
#             in_channels=config['encoder_out_nchannels'],
#             out_channels=config['encoder_out_nchannels'],
#             intra_model=intra_model,
#             num_layers=config['masknet_numlayers'],
#             norm=config['masknet_norm'],
#             K=config['masknet_chunksize'],
#             num_spks=config['masknet_numspks'],
#             skip_around_intra=config['masknet_extraskipconnection'],
#             linear_layer_after_inter_intra=config['masknet_useextralinearlayer'],
#         )
#         self.decoder = Decoder(
#             in_channels=config['encoder_out_nchannels'],
#             out_channels=config['encoder_in_nchannels'],
#             kernel_size=config['encoder_kernel_size'],
#             stride=config['encoder_kernel_size'] // 2,
#             bias=False,
#         )
#         self.num_spks = config['masknet_numspks']
#         self.sample_rate = config['sample_rate']
#
#         # Set device to gpu if available
#         device = 'cuda' if torch.cuda.is_available() else 'cpu'
#         self.to(device)
#         print(f'model initialised on {self.device}')
#
#     @property
#     def device(self):
#         return next(self.parameters()).device
#
#     def loadPretrained(self):
#         if not os.path.isdir(f'./model_weights/{self.config_name}'):
#             print("no checkpoints have been cached, getting them now...")
#             getCheckpoints(self.config_name)
#
#         #load the model checkpoints
#         self.encoder.load_state_dict(torch.load(f'model_weights/{self.config_name}/encoder.ckpt', map_location=torch.device(self.device)))
#         self.decoder.load_state_dict(torch.load(f'model_weights/{self.config_name}/decoder.ckpt', map_location=torch.device(self.device)))
#         self.masknet.load_state_dict(torch.load(f'model_weights/{self.config_name}/masknet.ckpt', map_location=torch.device(self.device)))
#
#     def inference(self, mix_file, output_dir):
#         '''
#         This is a helper function for inference on a single mixture file
#         '''
#
#         if not os.path.exists(output_dir):
#             os.makedirs(output_dir)
#
#         test_mix, sample_rate = torchaudio.load(mix_file)
#
#         if sample_rate != self.sample_rate:
#             raise Exception(f'Sampling rate must be {self.sample_rate}')
#
#         with torch.no_grad():
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.10.0+cu128)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->torchmetrics) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %%
# ==========================================================
# Imports & Configuration
# ==========================================================

import gc
import glob
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio

from tqdm.auto import tqdm

from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

from MossFormer2_standalone.model.mossformer2 import Mossformer2Wrapper
from MossFormer2_standalone.model.mossformer2_configs import (
    mossformer2_wsj0mix_3spk,
)
from torchmetrics.audio import ScaleInvariantSignalDistortionRatio

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

MAX_SPEAKERS = 8

LATENT_CHANNELS = 512

HIDDEN_DIM = 256

CONFIDENCE_THRESHOLD = 0.35

CROP_SIZE = 16000

torch.backends.cudnn.benchmark = True

sisdr = ScaleInvariantSignalDistortionRatio().to(DEVICE)

print("DEVICE :", DEVICE)
# Out:
# DEVICE : cuda

# %%
#Version 1

# ==========================================================
# Load Pretrained Model
# ==========================================================

backbone = Mossformer2Wrapper(
    mossformer2_wsj0mix_3spk
)

backbone.loadPretrained()

backbone.eval()

waveform, sr = torchaudio.load(
    "MossFormer2_samples_WSJ0-3mix/item0_mix.wav"
)

waveform = waveform.to(backbone.device)

with torch.no_grad():

    mix_w = backbone.encoder(waveform)

print("Waveform :", waveform.shape)
print("Encoder  :", mix_w.shape)

# ==========================================================
# Adaptive Multi Scale Temporal Module
# ==========================================================

class AdaptiveMultiScaleTemporalModule(nn.Module):

    def __init__(self, channels=LATENT_CHANNELS):

        super().__init__()

        reduced = channels // 4

        self.reduce = nn.Conv1d(
            channels,
            reduced,
            1,
        )

        self.dw3 = nn.Conv1d(
            reduced,
            reduced,
            3,
            padding=1,
            groups=reduced,
        )

        self.dw5 = nn.Conv1d(
            reduced,
            reduced,
            5,
            padding=2,
            groups=reduced,
        )

        self.dw9 = nn.Conv1d(
            reduced,
            reduced,
            9,
            padding=4,
            groups=reduced,
        )

        self.expand = nn.Conv1d(
            reduced * 3,
            channels,
            1,
        )

        self.refine = nn.Sequential(

            nn.Conv1d(
                channels,
                channels,
                1,
            ),

            nn.GELU()

        )

    def forward(self, x):

        identity = x

        x = self.reduce(x)

        x3 = self.dw3(x)

        x5 = self.dw5(x)

        x9 = self.dw9(x)

        x = torch.cat(
            [x3, x5, x9],
            dim=1,
        )

        x = self.expand(x)

        x = self.refine(x)

        return x + identity

# ==========================================================
# Adaptive Gated Feature Fusion (Stable V2)
# ==========================================================

class AdaptiveGatedFeatureFusion(nn.Module):

    def __init__(self, channels=LATENT_CHANNELS):

        super().__init__()

        self.gate = nn.Sequential(

            nn.Conv1d(
                channels,
                channels,
                kernel_size=1,
                bias=False,
            ),

            nn.BatchNorm1d(channels),

            nn.Sigmoid(),

        )

    def forward(

        self,

        original,

        enhanced,

    ):

        gate = self.gate(original)

        fused = original + 0.1 * gate * enhanced

        return fused
        
# ==========================================================
# Speaker Count Head
# ==========================================================

class SpeakerCountHead(nn.Module):

    def __init__(
        self,
        channels=LATENT_CHANNELS,
        hidden_dim=HIDDEN_DIM,
        max_speakers=MAX_SPEAKERS,
    ):

        super().__init__()

        self.pool = nn.AdaptiveAvgPool1d(1)

        self.classifier = nn.Sequential(

            nn.Linear(channels, hidden_dim),

            nn.GELU(),

            nn.Dropout(0.2),

            nn.Linear(hidden_dim, max_speakers)

        )

    def forward(self, x):

        x = self.pool(x)

        x = x.squeeze(-1)

        return self.classifier(x)

# ==========================================================
# Confidence Head
# ==========================================================

class ConfidenceHead(nn.Module):

    def __init__(
        self,
        channels=LATENT_CHANNELS,
        hidden_dim=HIDDEN_DIM,
        max_speakers=MAX_SPEAKERS,
    ):

        super().__init__()

        self.pool = nn.AdaptiveAvgPool1d(1)

        self.classifier = nn.Sequential(

            nn.Linear(channels, hidden_dim),
        
            nn.GELU(),
        
            nn.Dropout(0.2),
        
            nn.Linear(hidden_dim, max_speakers),
        
        )

    def forward(self, x):

        x = self.pool(x)

        x = x.squeeze(-1)

        return self.classifier(x)

# ==========================================================
# Enhanced Adaptive MossFormer
# ==========================================================

class EnhancedAdaptiveMossFormer(nn.Module):

    def __init__(self, config):

        super().__init__()

        self.backbone = Mossformer2Wrapper(config)

        self.backbone.loadPretrained()

        self.encoder = self.backbone.encoder

        self.masknet = self.backbone.masknet

        self.decoder = self.backbone.decoder

        self.num_spks = self.backbone.num_spks

        self.amtm = AdaptiveMultiScaleTemporalModule()

        self.agff = AdaptiveGatedFeatureFusion()

        self.speaker_counter = SpeakerCountHead()

        self.confidence_head = ConfidenceHead()

        for p in self.encoder.parameters():
            p.requires_grad = False

        for p in self.masknet.parameters():
            p.requires_grad = True

        for p in self.decoder.parameters():
            p.requires_grad = False

        # Train AMTM
        for p in self.amtm.parameters():
            p.requires_grad = True
        
        # Train AGFF
        for p in self.agff.parameters():
            p.requires_grad = True
        
        # Train Speaker Counter
        for p in self.speaker_counter.parameters():
            p.requires_grad = True
        
        # Train Confidence Head
        for p in self.confidence_head.parameters():
            p.requires_grad = True

    @property
    def device(self):
        return next(self.parameters()).device

    def forward(self, mixture):

        mix_w = self.encoder(mixture)

        enhanced = self.amtm(mix_w)

        enhanced = torch.tanh(enhanced)
        
        mix_w = self.agff(
            mix_w,
            enhanced,
        )

        speaker_logits = self.speaker_counter(mix_w)

        confidence = self.confidence_head(mix_w)

        est_mask = self.masknet(mix_w)

        mix_stack = torch.stack(
            [mix_w] * self.num_spks
        )

        sep_h = mix_stack * est_mask

        est_source = torch.cat(
            [
                self.decoder(sep_h[i]).unsqueeze(-1)
                for i in range(self.num_spks)
            ],
            dim=-1,
        )

        T_origin = mixture.size(1)

        T_est = est_source.size(1)

        if T_origin > T_est:

            est_source = F.pad(
                est_source,
                (0,0,0,T_origin-T_est)
            )

        else:

            est_source = est_source[:, :T_origin, :]

        return {

            "audio": est_source,

            "speaker_logits": speaker_logits,

            "confidence": confidence

        }

# ==========================================================
# Verify Model
# ==========================================================

gc.collect()

torch.cuda.empty_cache()

model = EnhancedAdaptiveMossFormer(
    mossformer2_wsj0mix_3spk
).to(DEVICE)

model.eval()

with torch.no_grad():

    outputs = model(waveform)

print("="*60)

print(outputs["audio"].shape)

print(outputs["speaker_logits"].shape)

print(outputs["confidence"].shape)

print("="*60)

total = sum(
    p.numel()
    for p in model.parameters()
)

trainable = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print("Total :", total)

print("Trainable :", trainable)

# ==========================================================
# Loss Function
# ==========================================================

class EnhancedMossFormerLoss(nn.Module):

    def __init__(
        self,
        separation_weight=0.75,
        speaker_weight=0.15,
        confidence_weight=0.10,
    ):

        super().__init__()

        self.log_sigma_sep = nn.Parameter(torch.zeros(1))
        self.log_sigma_spk = nn.Parameter(torch.zeros(1))
        self.log_sigma_conf = nn.Parameter(torch.zeros(1))

        self.separation_loss = nn.L1Loss()

        self.speaker_loss = nn.CrossEntropyLoss()

        self.confidence_loss = nn.BCEWithLogitsLoss()

    def forward(

        self,

        outputs,

        target_audio,

        target_num_speakers,

        target_confidence,

    ):
        print("audio NaN :", torch.isnan(outputs["audio"]).any().item())
        print("target NaN:", torch.isnan(target_audio).any().item())
        
        print("audio Inf :", torch.isinf(outputs["audio"]).any().item())
        print("target Inf:", torch.isinf(target_audio).any().item())
        
        sep = self.separation_loss(
            outputs["audio"],
            target_audio,
        )
        

        spk = self.speaker_loss(

            outputs["speaker_logits"],

            target_num_speakers,

        )

        conf = self.confidence_loss(

            outputs["confidence"],

            target_confidence,

        )

        weight_sep = torch.exp(
            torch.clamp(-self.log_sigma_sep, -5, 5)
        )
        
        weight_spk = torch.exp(
            torch.clamp(-self.log_sigma_spk, -5, 5)
        )
        
        weight_conf = torch.exp(
            torch.clamp(-self.log_sigma_conf, -5, 5)
        )
        
        loss_sep = (
            weight_sep * sep
            + self.log_sigma_sep
        )
        
        loss_spk = (
            weight_spk * spk
            + self.log_sigma_spk
        )
        
        loss_conf = (
            weight_conf * conf
            + self.log_sigma_conf
        )
        
        total = (
            loss_sep
            + loss_spk
            + loss_conf
        )

        print(
            f"log_sigma_sep  : {self.log_sigma_sep.item():.4f}"
        )
        print(
            f"log_sigma_spk  : {self.log_sigma_spk.item():.4f}"
        )
        print(
            f"log_sigma_conf : {self.log_sigma_conf.item():.4f}"
        )

        return {

            "total_loss": total,

            "separation_loss": sep,

            "speaker_loss": spk,

            "confidence_loss": conf,

            "log_sigma_sep": self.log_sigma_sep.detach(),

            "log_sigma_spk": self.log_sigma_spk.detach(),
            
            "log_sigma_conf": self.log_sigma_conf.detach(),

        }

# ==========================================================
# Optimizer
# ==========================================================

criterion = EnhancedMossFormerLoss().to(DEVICE)
print(next(criterion.parameters()).device)

optimizer = optim.AdamW(

    [
        {
            "params": model.parameters(),
        },
        {
            "params": criterion.parameters(),
        },
    ],

    lr=1e-4,

    weight_decay=1e-5,

)

scheduler = optim.lr_scheduler.CosineAnnealingLR(

    optimizer,

    T_max=20,

)

scaler = torch.amp.GradScaler("cuda")

print("Optimizer Ready")

# ==========================================================
# Dataset
# ==========================================================

class MossFormerDataset(Dataset):

    def __init__(

        self,

        root_dir,

    ):

        self.mixtures = sorted(

            glob.glob(

                os.path.join(

                    root_dir,

                    "*_mix.wav",

                )

            )

        )

    def __len__(self):

        return len(self.mixtures)

    def __getitem__(

        self,

        idx,

    ):

        mix_path = self.mixtures[idx]

        mixture, _ = torchaudio.load(

            mix_path

        )

        src1, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source1.wav",

            )

        )

        src2, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source2.wav",

            )

        )

        src3, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source3.wav",

            )

        )

        length = mixture.shape[1]

        if length > CROP_SIZE:

            start = torch.randint(

                0,

                length - CROP_SIZE,

                (1,),

            ).item()

            end = start + CROP_SIZE

            mixture = mixture[:, start:end]

            src1 = src1[:, start:end]

            src2 = src2[:, start:end]

            src3 = src3[:, start:end]

        sources = torch.stack(

            [

                src1.squeeze(0),

                src2.squeeze(0),

                src3.squeeze(0),

            ],

            dim=-1,

        )

        return {

            "mixture": mixture,

            "sources": sources,

            "num_speakers": torch.tensor(

                3,

                dtype=torch.long,

            ),

            "confidence": torch.tensor(

                [

                    1.,

                    1.,

                    1.,

                    0.,

                    0.,

                    0.,

                    0.,

                    0.,

                ],

                dtype=torch.float32,

            ),

        }

# ==========================================================
# DataLoader
# ==========================================================

def collate_fn(batch):

    mixtures = [

        x["mixture"].squeeze()

        for x in batch

    ]

    mixtures = pad_sequence(

        mixtures,

        batch_first=True,

    )

    sources = [

        x["sources"]

        for x in batch

    ]

    max_len = max(

        s.shape[0]

        for s in sources

    )

    padded = []

    for s in sources:

        if s.shape[0] < max_len:

            s = torch.cat(

                [

                    s,

                    torch.zeros(

                        max_len - s.shape[0],

                        3,

                    ),

                ],

                dim=0,

            )

        padded.append(s)

    return {

        "mixture": mixtures,

        "sources": torch.stack(padded),

        "num_speakers": torch.stack(

            [

                x["num_speakers"]

                for x in batch

            ]

        ),

        "confidence": torch.stack(

            [

                x["confidence"]

                for x in batch

            ]

        ),

    }

train_dataset = MossFormerDataset(

    "MossFormer2_samples_WSJ0-3mix"

)

train_loader = DataLoader(

    train_dataset,

    batch_size=1,

    shuffle=True,

    collate_fn=collate_fn,

)

print(len(train_dataset))
print(len(train_loader))

# ==========================================================
# Train One Epoch
# ==========================================================

def train_one_epoch(

    model,

    dataloader,

    optimizer,

    criterion,

    scaler,

    scheduler=None,

):

    model.train()

    running_loss = 0.0
    running_sep = 0.0
    running_spk = 0.0
    running_conf = 0.0

    progress = tqdm(
        dataloader,
        desc="Training",
    )

    for batch in progress:

        mixture = batch["mixture"].to(
            DEVICE,
            non_blocking=True,
        )

        sources = batch["sources"].to(
            DEVICE,
            non_blocking=True,
        )

        num_speakers = batch["num_speakers"].to(
            DEVICE,
            non_blocking=True,
        )

        confidence = batch["confidence"].to(
            DEVICE,
            non_blocking=True,
        )

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(

            device_type="cuda",

            enabled=False #torch.cuda.is_available(),

        ):

            outputs = model(mixture)

            losses = criterion(

                outputs,

                sources,

                num_speakers,

                confidence,

            )

            if torch.isnan(losses["separation_loss"]):
                print("NaN separation loss detected")
                break
            if torch.isnan(outputs["audio"]).any():
                print("NaN in separated audio")
                
            print("\n========== Forward Check ==========")

            for name, tensor in outputs.items():

                print(

                    name,

                    "NaN:", torch.isnan(tensor).any().item(),

                    "Inf:", torch.isinf(tensor).any().item(),

                )

            print("Total Loss :", losses["total_loss"].item())
            print("Sep Loss   :", losses["separation_loss"].item())
            print("Spk Loss   :", losses["speaker_loss"].item())
            print("Conf Loss  :", losses["confidence_loss"].item())

        scaler.scale(
            losses["total_loss"]
        ).backward()

        print("\n========== Gradient Check ==========")

        for name, param in model.named_parameters():

            if param.grad is None:
                continue

            if torch.isnan(param.grad).any():

                print(f"NaN Gradient : {name}")

                break

            if torch.isinf(param.grad).any():

                print(f"Inf Gradient : {name}")

                break

        scaler.unscale_(optimizer)

        torch.nn.utils.clip_grad_norm_(

            model.parameters(),

            max_norm=1.0,

        )

        scaler.step(optimizer)

        scaler.update()

        for name, param in model.named_parameters():

            if torch.isnan(param).any():

                print(f"NaN weights in {name}")

                raise RuntimeError("NaN weights detected")

        running_loss += losses["total_loss"].item()
        running_sep += losses["separation_loss"].item()
        running_spk += losses["speaker_loss"].item()
        running_conf += losses["confidence_loss"].item()

        progress.set_postfix(

            Loss=f"{running_loss/(progress.n+1):.4f}",

            Sep=f"{running_sep/(progress.n+1):.4f}",

            Spk=f"{running_spk/(progress.n+1):.4f}",

            Conf=f"{running_conf/(progress.n+1):.4f}",

        )

    if scheduler is not None:

        scheduler.step()

    return {

        "loss": running_loss / len(dataloader),

        "separation_loss": running_sep / len(dataloader),

        "speaker_loss": running_spk / len(dataloader),

        "confidence_loss": running_conf / len(dataloader),

    }

# ==========================================================
# Validation
# ==========================================================

@torch.no_grad()
def validate(

    model,

    dataloader,

    criterion,

):

    model.eval()

    running = 0.0
    running_sisdr = 0.0

    for batch in dataloader:

        mixture = batch["mixture"].to(DEVICE)

        target_audio = batch["sources"].to(DEVICE)

        target_num_speakers = batch["num_speakers"].to(DEVICE)

        target_confidence = batch["confidence"].to(DEVICE)

        outputs = model(mixture)

        losses = criterion(

            outputs,

            target_audio,

            target_num_speakers,

            target_confidence,

        )

        score = sisdr(

            outputs["audio"].permute(0, 2, 1),

            target_audio.permute(0, 2, 1),

        )

        running += losses["total_loss"].item()

        running_sisdr += score.item()

    return {

        "loss": running / len(dataloader),

        "sisdr": running_sisdr / len(dataloader),

    }

# ==========================================================
# Train
# ==========================================================

gc.collect()

torch.cuda.empty_cache()

best_loss = float("inf")

NUM_EPOCHS = 20

for epoch in range(NUM_EPOCHS):

    print("\n" + "=" * 60)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
    print("=" * 60)

    history = train_one_epoch(

        model=model,

        dataloader=train_loader,

        optimizer=optimizer,

        criterion=criterion,

        scaler=scaler,

        scheduler=scheduler,

    )

    metrics = validate(

        model,

        train_loader,

        criterion,

    )

    print("\nTraining")

    for key, value in history.items():

        print(f"{key:20}: {value:.5f}")

    print("\nValidation")

    print(f"Loss               : {metrics['loss']:.5f}")

    print(f"SI-SDR             : {metrics['sisdr']:.5f}")

    if metrics["loss"] < best_loss:

        best_loss = metrics["loss"]

        torch.save(

            {

                "model": model.state_dict(),

                "optimizer": optimizer.state_dict(),

                "epoch": epoch,

                "loss": metrics["loss"],

            },

            "best_enhanced_mossformer.pth",

        )

        print("\n✓ Best model saved.")
# Out:
# mossformer2-wsj0mix-3spk config loaded
# model initialised on cuda:0
# Waveform : torch.Size([1, 44920])
# Encoder  : torch.Size([1, 512, 5614])
# mossformer2-wsj0mix-3spk config loaded
# model initialised on cuda:0
# ============================================================
# torch.Size([1, 44920, 3])
# torch.Size([1, 8])
# torch.Size([1, 8])
# ============================================================
# Total : 57056002
# Trainable : 57039618
# cuda:0
# Optimizer Ready
# 38
# 38
#
# ============================================================
# Epoch 1/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : 0.0000
# log_sigma_spk  : 0.0000
# log_sigma_conf : 0.0000
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.172497510910034
# Sep Loss   : 0.3866754472255707
# Spk Loss   : 2.097289562225342
# Conf Loss  : 0.6885326504707336
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0001
# log_sigma_spk  : 0.0001
# log_sigma_conf : -0.0001
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.1876473426818848
# Sep Loss   : 0.41060343384742737
# Spk Loss   : 2.0896518230438232
# Conf Loss  : 0.6875911951065063
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0002
# log_sigma_spk  : 0.0002
# log_sigma_conf : -0.0002
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.2921273708343506
# Sep Loss   : 0.5274662971496582
# Spk Loss   : 2.075916051864624
# Conf Loss  : 0.6891167163848877
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0003
# log_sigma_spk  : 0.0003
# log_sigma_conf : -0.0003
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.4115281105041504
# Sep Loss   : 0.6534284949302673
# Spk Loss   : 2.065654993057251
# Conf Loss  : 0.6929595470428467
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0004
# log_sigma_spk  : 0.0004
# log_sigma_conf : -0.0004
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0861215591430664
# Sep Loss   : 0.3216952383518219
# Spk Loss   : 2.0832931995391846
# Conf Loss  : 0.6819601058959961
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0005
# log_sigma_spk  : 0.0005
# log_sigma_conf : -0.0005
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9755430221557617
# Sep Loss   : 0.2455112636089325
# Spk Loss   : 2.047963857650757
# Conf Loss  : 0.6831201314926147
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0006
# log_sigma_spk  : 0.0006
# log_sigma_conf : -0.0006
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.138542890548706
# Sep Loss   : 0.4160389006137848
# Spk Loss   : 2.043078899383545
# Conf Loss  : 0.6805860996246338
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0007
# log_sigma_spk  : 0.0007
# log_sigma_conf : -0.0007
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.1099419593811035
# Sep Loss   : 0.42644596099853516
# Spk Loss   : 2.0038437843322754
# Conf Loss  : 0.680972158908844
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0008
# log_sigma_spk  : 0.0008
# log_sigma_conf : -0.0008
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.115044593811035
# Sep Loss   : 0.4161606431007385
# Spk Loss   : 2.0194365978240967
# Conf Loss  : 0.6809757947921753
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0009
# log_sigma_spk  : 0.0009
# log_sigma_conf : -0.0009
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0287652015686035
# Sep Loss   : 0.39252978563308716
# Spk Loss   : 1.9608120918273926
# Conf Loss  : 0.6771143078804016
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0010
# log_sigma_spk  : 0.0010
# log_sigma_conf : -0.0010
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0505058765411377
# Sep Loss   : 0.38335904479026794
# Spk Loss   : 1.9941555261611938
# Conf Loss  : 0.6749144792556763
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0011
# log_sigma_spk  : 0.0011
# log_sigma_conf : -0.0011
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0562734603881836
# Sep Loss   : 0.3582565188407898
# Spk Loss   : 2.0268163681030273
# Conf Loss  : 0.6733806133270264
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0012
# log_sigma_spk  : 0.0012
# log_sigma_conf : -0.0012
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.936922550201416
# Sep Loss   : 0.32620877027511597
# Spk Loss   : 1.9466160535812378
# Conf Loss  : 0.6664266586303711
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0013
# log_sigma_spk  : 0.0013
# log_sigma_conf : -0.0013
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.899428367614746
# Sep Loss   : 0.25722941756248474
# Spk Loss   : 1.9730908870697021
# Conf Loss  : 0.6717473268508911
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0014
# log_sigma_spk  : 0.0014
# log_sigma_conf : -0.0014
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.106825828552246
# Sep Loss   : 0.4254525601863861
# Spk Loss   : 2.0237691402435303
# Conf Loss  : 0.6602998375892639
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0015
# log_sigma_spk  : 0.0015
# log_sigma_conf : -0.0015
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.923830986022949
# Sep Loss   : 0.330471396446228
# Spk Loss   : 1.9347434043884277
# Conf Loss  : 0.6615120768547058
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0016
# log_sigma_spk  : 0.0016
# log_sigma_conf : -0.0016
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8857038021087646
# Sep Loss   : 0.30154329538345337
# Spk Loss   : 1.925950527191162
# Conf Loss  : 0.6613317131996155
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0017
# log_sigma_spk  : 0.0017
# log_sigma_conf : -0.0017
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.830735683441162
# Sep Loss   : 0.19195051491260529
# Spk Loss   : 1.97327721118927
# Conf Loss  : 0.6690773963928223
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0018
# log_sigma_spk  : 0.0018
# log_sigma_conf : -0.0018
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.910388946533203
# Sep Loss   : 0.3139389157295227
# Spk Loss   : 1.9370115995407104
# Conf Loss  : 0.6629465818405151
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0019
# log_sigma_spk  : 0.0019
# log_sigma_conf : -0.0019
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8911101818084717
# Sep Loss   : 0.3280492424964905
# Spk Loss   : 1.91374933719635
# Conf Loss  : 0.6529643535614014
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0020
# log_sigma_spk  : 0.0020
# log_sigma_conf : -0.0020
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.788754463195801
# Sep Loss   : 0.10460899770259857
# Spk Loss   : 2.0180823802948
# Conf Loss  : 0.6705276966094971
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0021
# log_sigma_spk  : 0.0021
# log_sigma_conf : -0.0021
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8905911445617676
# Sep Loss   : 0.3032139837741852
# Spk Loss   : 1.932874083518982
# Conf Loss  : 0.6586230993270874
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0022
# log_sigma_spk  : 0.0022
# log_sigma_conf : -0.0022
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.858940601348877
# Sep Loss   : 0.3187035322189331
# Spk Loss   : 1.9000827074050903
# Conf Loss  : 0.6443983316421509
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0023
# log_sigma_spk  : 0.0023
# log_sigma_conf : -0.0023
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9170045852661133
# Sep Loss   : 0.5246564149856567
# Spk Loss   : 1.766012191772461
# Conf Loss  : 0.6300251483917236
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0024
# log_sigma_spk  : 0.0024
# log_sigma_conf : -0.0024
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.7451510429382324
# Sep Loss   : 0.14038190245628357
# Spk Loss   : 1.9502263069152832
# Conf Loss  : 0.6596859693527222
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0025
# log_sigma_spk  : 0.0025
# log_sigma_conf : -0.0025
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.7755117416381836
# Sep Loss   : 0.3041047751903534
# Spk Loss   : 1.8317134380340576
# Conf Loss  : 0.6443846225738525
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0026
# log_sigma_spk  : 0.0026
# log_sigma_conf : -0.0026
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.7416110038757324
# Sep Loss   : 0.2192305028438568
# Spk Loss   : 1.8782280683517456
# Conf Loss  : 0.6493595838546753
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0027
# log_sigma_spk  : 0.0026
# log_sigma_conf : -0.0027
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.7022714614868164
# Sep Loss   : 0.17847619950771332
# Spk Loss   : 1.8820149898529053
# Conf Loss  : 0.6473146677017212
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0028
# log_sigma_spk  : 0.0027
# log_sigma_conf : -0.0028
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.6534245014190674
# Sep Loss   : 0.22464440762996674
# Spk Loss   : 1.7897605895996094
# Conf Loss  : 0.6443837881088257
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0029
# log_sigma_spk  : 0.0028
# log_sigma_conf : -0.0029
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.6413660049438477
# Sep Loss   : 0.17683617770671844
# Spk Loss   : 1.8281840085983276
# Conf Loss  : 0.6421586871147156
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0031
# log_sigma_spk  : 0.0029
# log_sigma_conf : -0.0030
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.6219396591186523
# Sep Loss   : 0.1903039962053299
# Spk Loss   : 1.803318977355957
# Conf Loss  : 0.6342408657073975
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0032
# log_sigma_spk  : 0.0030
# log_sigma_conf : -0.0031
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.5819315910339355
# Sep Loss   : 0.1700628399848938
# Spk Loss   : 1.7840009927749634
# Conf Loss  : 0.6339966654777527
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0033
# log_sigma_spk  : 0.0031
# log_sigma_conf : -0.0032
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.5665714740753174
# Sep Loss   : 0.16562843322753906
# Spk Loss   : 1.7766921520233154
# Conf Loss  : 0.6305818557739258
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0034
# log_sigma_spk  : 0.0032
# log_sigma_conf : -0.0033
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.5691633224487305
# Sep Loss   : 0.12231755256652832
# Spk Loss   : 1.8131334781646729
# Conf Loss  : 0.6404720544815063
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0035
# log_sigma_spk  : 0.0033
# log_sigma_conf : -0.0035
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.5178751945495605
# Sep Loss   : 0.1330966353416443
# Spk Loss   : 1.7596685886383057
# Conf Loss  : 0.6318925619125366
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0036
# log_sigma_spk  : 0.0034
# log_sigma_conf : -0.0036
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.472155809402466
# Sep Loss   : 0.11922357231378555
# Spk Loss   : 1.731248378753662
# Conf Loss  : 0.6286334991455078
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0037
# log_sigma_spk  : 0.0035
# log_sigma_conf : -0.0037
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.4474730491638184
# Sep Loss   : 0.12027159333229065
# Spk Loss   : 1.713988184928894
# Conf Loss  : 0.6203302145004272
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0038
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0038
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.357323169708252
# Sep Loss   : 0.14066803455352783
# Spk Loss   : 1.6170109510421753
# Conf Loss  : 0.6065902709960938
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
#
# Training
# loss                : 2.86470
# separation_loss     : 0.29130
# speaker_loss        : 1.91875
# confidence_loss     : 0.65829
#
# Validation
# Loss               : 2.40823
# SI-SDR             : -6.03880
#
# ✓ Best model saved.
#
# ============================================================
# Epoch 2/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0039
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3471550941467285
# Sep Loss   : 0.11886409670114517
# Spk Loss   : 1.618776559829712
# Conf Loss  : 0.6167033910751343
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0040
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0040
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3747355937957764
# Sep Loss   : 0.09748156368732452
# Spk Loss   : 1.6645451784133911
# Conf Loss  : 0.6203303337097168
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0042
# log_sigma_spk  : 0.0038
# log_sigma_conf : -0.0041
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.364750385284424
# Sep Loss   : 0.08917765319347382
# Spk Loss   : 1.6798715591430664
# Conf Loss  : 0.6036797761917114
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0043
# log_sigma_spk  : 0.0039
# log_sigma_conf : -0.0042
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.4146339893341064
# Sep Loss   : 0.059495389461517334
# Spk Loss   : 1.7396326065063477
# Conf Loss  : 0.623958945274353
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0044
# log_sigma_spk  : 0.0040
# log_sigma_conf : -0.0043
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.288787841796875
# Sep Loss   : 0.06462734192609787
# Spk Loss   : 1.6375360488891602
# Conf Loss  : 0.5949797630310059
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0045
# log_sigma_spk  : 0.0041
# log_sigma_conf : -0.0044
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.278383255004883
# Sep Loss   : 0.07260000705718994
# Spk Loss   : 1.613096833229065
# Conf Loss  : 0.601080596446991
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0046
# log_sigma_spk  : 0.0041
# log_sigma_conf : -0.0045
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.2671399116516113
# Sep Loss   : 0.04796444624662399
# Spk Loss   : 1.6232960224151611
# Conf Loss  : 0.6046105623245239
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0047
# log_sigma_spk  : 0.0042
# log_sigma_conf : -0.0046
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.191096305847168
# Sep Loss   : 0.06151098385453224
# Spk Loss   : 1.5516380071640015
# Conf Loss  : 0.5865955352783203
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0048
# log_sigma_spk  : 0.0043
# log_sigma_conf : -0.0047
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.119171619415283
# Sep Loss   : 0.05546371266245842
# Spk Loss   : 1.4968609809875488
# Conf Loss  : 0.5755356550216675
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0049
# log_sigma_spk  : 0.0044
# log_sigma_conf : -0.0048
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.074030637741089
# Sep Loss   : 0.05829013139009476
# Spk Loss   : 1.4604235887527466
# Conf Loss  : 0.5640792846679688
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0051
# log_sigma_spk  : 0.0045
# log_sigma_conf : -0.0049
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.228006601333618
# Sep Loss   : 0.039358124136924744
# Spk Loss   : 1.601354956626892
# Conf Loss  : 0.5968066453933716
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0052
# log_sigma_spk  : 0.0045
# log_sigma_conf : -0.0050
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.006046772003174
# Sep Loss   : 0.0541800931096077
# Spk Loss   : 1.3969779014587402
# Conf Loss  : 0.5637655854225159
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0053
# log_sigma_spk  : 0.0046
# log_sigma_conf : -0.0052
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.009406328201294
# Sep Loss   : 0.04284141957759857
# Spk Loss   : 1.4132426977157593
# Conf Loss  : 0.5625250339508057
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0054
# log_sigma_spk  : 0.0047
# log_sigma_conf : -0.0053
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.070460319519043
# Sep Loss   : 0.04061182960867882
# Spk Loss   : 1.4614993333816528
# Conf Loss  : 0.5778952836990356
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0055
# log_sigma_spk  : 0.0048
# log_sigma_conf : -0.0054
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.012094020843506
# Sep Loss   : 0.03697395697236061
# Spk Loss   : 1.4233331680297852
# Conf Loss  : 0.5614492893218994
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0056
# log_sigma_spk  : 0.0048
# log_sigma_conf : -0.0055
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.9517858028411865
# Sep Loss   : 0.04305438697338104
# Spk Loss   : 1.36510169506073
# Conf Loss  : 0.5532106161117554
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0058
# log_sigma_spk  : 0.0049
# log_sigma_conf : -0.0056
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.850926160812378
# Sep Loss   : 0.03604913130402565
# Spk Loss   : 1.2866119146347046
# Conf Loss  : 0.5377742052078247
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0059
# log_sigma_spk  : 0.0049
# log_sigma_conf : -0.0057
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.189016819000244
# Sep Loss   : 0.03333517909049988
# Spk Loss   : 1.5725197792053223
# Conf Loss  : 0.5939568281173706
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0060
# log_sigma_spk  : 0.0050
# log_sigma_conf : -0.0058
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.0929856300354004
# Sep Loss   : 0.039618346840143204
# Spk Loss   : 1.483939528465271
# Conf Loss  : 0.5800160765647888
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0061
# log_sigma_spk  : 0.0051
# log_sigma_conf : -0.0059
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.098315715789795
# Sep Loss   : 0.027804702520370483
# Spk Loss   : 1.507251262664795
# Conf Loss  : 0.5742602944374084
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0062
# log_sigma_spk  : 0.0051
# log_sigma_conf : -0.0060
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8088306188583374
# Sep Loss   : 0.04780522733926773
# Spk Loss   : 1.2564493417739868
# Conf Loss  : 0.5147185325622559
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0063
# log_sigma_spk  : 0.0052
# log_sigma_conf : -0.0062
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7274889945983887
# Sep Loss   : 0.033252231776714325
# Spk Loss   : 1.1799485683441162
# Conf Loss  : 0.5242465138435364
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0064
# log_sigma_spk  : 0.0053
# log_sigma_conf : -0.0063
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8073409795761108
# Sep Loss   : 0.03700442239642143
# Spk Loss   : 1.248888373374939
# Conf Loss  : 0.5318706035614014
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0066
# log_sigma_spk  : 0.0053
# log_sigma_conf : -0.0064
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.6759889125823975
# Sep Loss   : 0.035391926765441895
# Spk Loss   : 1.1349775791168213
# Conf Loss  : 0.5157293677330017
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0067
# log_sigma_spk  : 0.0054
# log_sigma_conf : -0.0065
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.627839207649231
# Sep Loss   : 0.033753909170627594
# Spk Loss   : 1.1064549684524536
# Conf Loss  : 0.49788761138916016
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0068
# log_sigma_spk  : 0.0054
# log_sigma_conf : -0.0066
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8703601360321045
# Sep Loss   : 0.029015325009822845
# Spk Loss   : 1.329483985900879
# Conf Loss  : 0.5233588814735413
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0069
# log_sigma_spk  : 0.0055
# log_sigma_conf : -0.0067
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7875771522521973
# Sep Loss   : 0.03361259400844574
# Spk Loss   : 1.2573490142822266
# Conf Loss  : 0.5079744458198547
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0070
# log_sigma_spk  : 0.0055
# log_sigma_conf : -0.0069
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.6560550928115845
# Sep Loss   : 0.03589361533522606
# Spk Loss   : 1.143113374710083
# Conf Loss  : 0.4880794882774353
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0071
# log_sigma_spk  : 0.0056
# log_sigma_conf : -0.0070
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3299493789672852
# Sep Loss   : 0.04409375041723251
# Spk Loss   : 0.8467726111412048
# Conf Loss  : 0.44886496663093567
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0072
# log_sigma_spk  : 0.0056
# log_sigma_conf : -0.0071
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.5595502853393555
# Sep Loss   : 0.035065703094005585
# Spk Loss   : 1.0725855827331543
# Conf Loss  : 0.46307286620140076
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0074
# log_sigma_spk  : 0.0056
# log_sigma_conf : -0.0072
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.500713586807251
# Sep Loss   : 0.02882888726890087
# Spk Loss   : 1.007175326347351
# Conf Loss  : 0.4756474494934082
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0075
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0073
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.5971064567565918
# Sep Loss   : 0.024590546265244484
# Spk Loss   : 1.0865874290466309
# Conf Loss  : 0.49736011028289795
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0076
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0074
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3923933506011963
# Sep Loss   : 0.03723963722586632
# Spk Loss   : 0.8974027633666992
# Conf Loss  : 0.468403160572052
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0077
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0076
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.312853217124939
# Sep Loss   : 0.048332225531339645
# Spk Loss   : 0.8094965815544128
# Conf Loss  : 0.46528416872024536
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0078
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0077
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3061532974243164
# Sep Loss   : 0.04930255934596062
# Spk Loss   : 0.8347423076629639
# Conf Loss  : 0.43292298913002014
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0079
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0078
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.2115617990493774
# Sep Loss   : 0.0421159453690052
# Spk Loss   : 0.7618710398674011
# Conf Loss  : 0.41831690073013306
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0080
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0079
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3955668210983276
# Sep Loss   : 0.03576480969786644
# Spk Loss   : 0.9218961596488953
# Conf Loss  : 0.44954657554626465
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0081
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.4100538492202759
# Sep Loss   : 0.0326484851539135
# Spk Loss   : 0.9268794059753418
# Conf Loss  : 0.4622931182384491
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
#
# Training
# loss                : 1.87385
# separation_loss     : 0.04692
# speaker_loss        : 1.30052
# confidence_loss     : 0.53628
#
# Validation
# Loss               : 1.27719
# SI-SDR             : -10.81969
#
# ✓ Best model saved.
#
# ============================================================
# Epoch 3/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0083
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0082
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3498766422271729
# Sep Loss   : 0.032295677810907364
# Spk Loss   : 0.8676691651344299
# Conf Loss  : 0.46152162551879883
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0084
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0083
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.267040729522705
# Sep Loss   : 0.027078954502940178
# Spk Loss   : 0.8165816068649292
# Conf Loss  : 0.43513041734695435
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0085
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0084
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.2773826122283936
# Sep Loss   : 0.030035752803087234
# Spk Loss   : 0.8226983547210693
# Conf Loss  : 0.43657201528549194
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0086
# log_sigma_spk  : 0.0058
# ...
# Sep Loss   : 0.015161493793129921
# Spk Loss   : 0.0022499265614897013
# Conf Loss  : 0.005182888358831406
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09004655480384827
# Sep Loss   : 0.020216122269630432
# Spk Loss   : 0.0015307862777262926
# Conf Loss  : 0.0067791445180773735
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09801635146141052
# Sep Loss   : 0.016898224130272865
# Spk Loss   : 0.001668134005740285
# Conf Loss  : 0.002350889379158616
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08556966483592987
# Sep Loss   : 0.0165364071726799
# Spk Loss   : 0.0077960980124771595
# Conf Loss  : 0.008558491244912148
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08884385228157043
# Sep Loss   : 0.017614956945180893
# Spk Loss   : 0.0043901256285607815
# Conf Loss  : 0.007710227742791176
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09847195446491241
# Sep Loss   : 0.016305938363075256
# Spk Loss   : 0.001416633022017777
# Conf Loss  : 0.002757422858849168
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09546470642089844
# Sep Loss   : 0.01029154285788536
# Spk Loss   : 0.004784919787198305
# Conf Loss  : 0.00829570647329092
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0847247987985611
# Sep Loss   : 0.027289194986224174
# Spk Loss   : 0.0017431078013032675
# Conf Loss  : 0.0046239751391112804
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.090236596763134
# Sep Loss   : 0.016359299421310425
# Spk Loss   : 0.0032225127797573805
# Conf Loss  : 0.008783381432294846
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09025333821773529
# Sep Loss   : 0.01563410460948944
# Spk Loss   : 0.003572868648916483
# Conf Loss  : 0.009146121330559254
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.070155568420887
# Sep Loss   : 0.013997460715472698
# Spk Loss   : 0.01658298820257187
# Conf Loss  : 0.017158757895231247
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08533778041601181
# Sep Loss   : 0.017852088436484337
# Spk Loss   : 0.007897934876382351
# Conf Loss  : 0.007386814337223768
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09426960349082947
# Sep Loss   : 0.022818975150585175
# Spk Loss   : 0.0005321278586052358
# Conf Loss  : 0.0011698531452566385
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08549393713474274
# Sep Loss   : 0.02958070859313011
# Spk Loss   : 0.0010661162668839097
# Conf Loss  : 0.00228948425501585
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09428229928016663
# Sep Loss   : 0.018068667501211166
# Spk Loss   : 0.0022691949270665646
# Conf Loss  : 0.004177185241132975
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09048502147197723
# Sep Loss   : 0.02378787286579609
# Spk Loss   : 0.0018511555390432477
# Conf Loss  : 0.002524071605876088
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09474578499794006
# Sep Loss   : 0.018932892009615898
# Spk Loss   : 0.0017403707606717944
# Conf Loss  : 0.00339933461509645
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09125620126724243
# Sep Loss   : 0.023297760635614395
# Spk Loss   : 0.0015695883193984628
# Conf Loss  : 0.002556159859523177
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08805601298809052
# Sep Loss   : 0.024425048381090164
# Spk Loss   : 0.0009895433904603124
# Conf Loss  : 0.0050551919266581535
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.10052190721035004
# Sep Loss   : 0.012916025705635548
# Spk Loss   : 0.0019030333496630192
# Conf Loss  : 0.003720927517861128
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0291
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09419520944356918
# Sep Loss   : 0.0144294872879982
# Spk Loss   : 0.003584628226235509
# Conf Loss  : 0.006596411112695932
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0834549069404602
# Sep Loss   : 0.021855033934116364
# Spk Loss   : 0.006112927105277777
# Conf Loss  : 0.006972053088247776
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09044557809829712
# Sep Loss   : 0.020726662129163742
# Spk Loss   : 0.0019249258330091834
# Conf Loss  : 0.00554321613162756
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0292
# log_sigma_conf : -0.0486
#
# Training
# loss                : -0.08988
# separation_loss     : 0.01874
# speaker_loss        : 0.00407
# confidence_loss     : 0.00592
#
# Validation
# Loss               : -0.09261
# SI-SDR             : 3.46490
#
# ✓ Best model saved.

# %%
#Version 2

# ==========================================================
# Load Pretrained Model
# ==========================================================

backbone = Mossformer2Wrapper(
    mossformer2_wsj0mix_3spk
)

backbone.loadPretrained()

backbone.eval()

waveform, sr = torchaudio.load(
    "MossFormer2_samples_WSJ0-3mix/item0_mix.wav"
)

waveform = waveform.to(backbone.device)

with torch.no_grad():

    mix_w = backbone.encoder(waveform)

print("Waveform :", waveform.shape)
print("Encoder  :", mix_w.shape)

# ==========================================================
# Adaptive Multi Scale Temporal Module
# ==========================================================

class AdaptiveMultiScaleTemporalModule(nn.Module):

    def __init__(self, channels=LATENT_CHANNELS):

        super().__init__()

        reduced = channels // 4

        self.reduce = nn.Conv1d(
            channels,
            reduced,
            1,
        )

        self.dw3 = nn.Conv1d(
            reduced,
            reduced,
            3,
            padding=1,
            groups=reduced,
        )

        self.dw5 = nn.Conv1d(
            reduced,
            reduced,
            5,
            padding=2,
            groups=reduced,
        )

        self.dw9 = nn.Conv1d(
            reduced,
            reduced,
            9,
            padding=4,
            groups=reduced,
        )

        self.expand = nn.Conv1d(
            reduced * 3,
            channels,
            1,
        )

        self.refine = nn.Sequential(

            nn.Conv1d(
                channels,
                channels,
                1,
            ),

            nn.GELU()

        )

    def forward(self, x):

        identity = x

        x = self.reduce(x)

        x3 = self.dw3(x)

        x5 = self.dw5(x)

        x9 = self.dw9(x)

        x = torch.cat(
            [x3, x5, x9],
            dim=1,
        )

        x = self.expand(x)

        x = self.refine(x)

        return x + identity

# ==========================================================
# Adaptive Gated Feature Fusion (Stable V2)
# ==========================================================

class AdaptiveGatedFeatureFusion(nn.Module):

    def __init__(self, channels=LATENT_CHANNELS):

        super().__init__()

        self.gate = nn.Sequential(

            nn.Conv1d(
                channels,
                channels,
                kernel_size=1,
                bias=False,
            ),

            nn.BatchNorm1d(channels),

            nn.Sigmoid(),

        )

    def forward(

        self,

        original,

        enhanced,

    ):

        gate = self.gate(original)

        fused = original + 0.1 * gate * enhanced

        return fused
        
# ==========================================================
# Speaker Count Head
# ==========================================================

class SpeakerCountHead(nn.Module):

    def __init__(
        self,
        channels=LATENT_CHANNELS,
        hidden_dim=HIDDEN_DIM,
        max_speakers=MAX_SPEAKERS,
    ):

        super().__init__()

        self.pool = nn.AdaptiveAvgPool1d(1)

        self.classifier = nn.Sequential(

            nn.Linear(channels, hidden_dim),

            nn.GELU(),

            nn.Dropout(0.2),

            nn.Linear(hidden_dim, max_speakers)

        )

    def forward(self, x):

        x = self.pool(x)

        x = x.squeeze(-1)

        return self.classifier(x)

# ==========================================================
# Confidence Head
# ==========================================================

class ConfidenceHead(nn.Module):

    def __init__(
        self,
        channels=LATENT_CHANNELS,
        hidden_dim=HIDDEN_DIM,
        max_speakers=MAX_SPEAKERS,
    ):

        super().__init__()

        self.pool = nn.AdaptiveAvgPool1d(1)

        self.classifier = nn.Sequential(

            nn.Linear(channels, hidden_dim),
        
            nn.GELU(),
        
            nn.Dropout(0.2),
        
            nn.Linear(hidden_dim, max_speakers),
        
        )

    def forward(self, x):

        x = self.pool(x)

        x = x.squeeze(-1)

        return self.classifier(x)

# ==========================================================
# Enhanced Adaptive MossFormer
# ==========================================================

class EnhancedAdaptiveMossFormer(nn.Module):

    def __init__(self, config):

        super().__init__()

        self.backbone = Mossformer2Wrapper(config)

        self.backbone.loadPretrained()

        self.encoder = self.backbone.encoder

        self.masknet = self.backbone.masknet

        self.decoder = self.backbone.decoder

        self.num_spks = self.backbone.num_spks

        self.amtm = AdaptiveMultiScaleTemporalModule()

        self.agff = AdaptiveGatedFeatureFusion()

        self.speaker_counter = SpeakerCountHead()

        self.confidence_head = ConfidenceHead()

        for p in self.encoder.parameters():
            p.requires_grad = False

        for p in self.masknet.parameters():
            p.requires_grad = True

        for p in self.decoder.parameters():
            p.requires_grad = False

        # Train AMTM
        for p in self.amtm.parameters():
            p.requires_grad = True
        
        # Train AGFF
        for p in self.agff.parameters():
            p.requires_grad = True
        
        # Train Speaker Counter
        for p in self.speaker_counter.parameters():
            p.requires_grad = True
        
        # Train Confidence Head
        for p in self.confidence_head.parameters():
            p.requires_grad = True

    @property
    def device(self):
        return next(self.parameters()).device

    def forward(self, mixture):

        mix_w = self.encoder(mixture)

        enhanced = self.amtm(mix_w)

        enhanced = torch.tanh(enhanced)
        
        mix_w = self.agff(
            mix_w,
            enhanced,
        )

        speaker_logits = self.speaker_counter(mix_w)

        confidence = self.confidence_head(mix_w)

        est_mask = self.masknet(mix_w)

        mix_stack = torch.stack(
            [mix_w] * self.num_spks
        )

        sep_h = mix_stack * est_mask

        est_source = torch.cat(
            [
                self.decoder(sep_h[i]).unsqueeze(-1)
                for i in range(self.num_spks)
            ],
            dim=-1,
        )

        T_origin = mixture.size(1)

        T_est = est_source.size(1)

        if T_origin > T_est:

            est_source = F.pad(
                est_source,
                (0,0,0,T_origin-T_est)
            )

        else:

            est_source = est_source[:, :T_origin, :]

        return {

            "audio": est_source,

            "speaker_logits": speaker_logits,

            "confidence": confidence

        }

# ==========================================================
# Verify Model
# ==========================================================

gc.collect()

torch.cuda.empty_cache()

model = EnhancedAdaptiveMossFormer(
    mossformer2_wsj0mix_3spk
).to(DEVICE)

model.eval()

with torch.no_grad():

    outputs = model(waveform)

print("="*60)

print(outputs["audio"].shape)

print(outputs["speaker_logits"].shape)

print(outputs["confidence"].shape)

print("="*60)

total = sum(
    p.numel()
    for p in model.parameters()
)

trainable = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print("Total :", total)

print("Trainable :", trainable)

# ==========================================================
# Loss Function
# ==========================================================

class EnhancedMossFormerLoss(nn.Module):

    def __init__(
        self,
        separation_weight=0.75,
        speaker_weight=0.15,
        confidence_weight=0.10,
    ):

        super().__init__()

        self.log_sigma_sep = nn.Parameter(torch.zeros(1))
        self.log_sigma_spk = nn.Parameter(torch.zeros(1))
        self.log_sigma_conf = nn.Parameter(torch.zeros(1))

        self.separation_loss = nn.L1Loss()

        self.speaker_loss = nn.CrossEntropyLoss()

        self.confidence_loss = nn.BCEWithLogitsLoss()

    def forward(

        self,

        outputs,

        target_audio,

        target_num_speakers,

        target_confidence,

    ):
        print("audio NaN :", torch.isnan(outputs["audio"]).any().item())
        print("target NaN:", torch.isnan(target_audio).any().item())
        
        print("audio Inf :", torch.isinf(outputs["audio"]).any().item())
        print("target Inf:", torch.isinf(target_audio).any().item())
        
        sep = self.separation_loss(
            outputs["audio"],
            target_audio,
        )
        

        spk = self.speaker_loss(

            outputs["speaker_logits"],

            target_num_speakers,

        )

        conf = self.confidence_loss(

            outputs["confidence"],

            target_confidence,

        )

        weight_sep = torch.exp(
            torch.clamp(-self.log_sigma_sep, -5, 5)
        )
        
        weight_spk = torch.exp(
            torch.clamp(-self.log_sigma_spk, -5, 5)
        )
        
        weight_conf = torch.exp(
            torch.clamp(-self.log_sigma_conf, -5, 5)
        )
        
        loss_sep = (
            weight_sep * sep
            + self.log_sigma_sep
        )
        
        loss_spk = (
            weight_spk * spk
            + self.log_sigma_spk
        )
        
        loss_conf = (
            weight_conf * conf
            + self.log_sigma_conf
        )
        
        total = (
            loss_sep
            + loss_spk
            + loss_conf
        )

        print(
            f"log_sigma_sep  : {self.log_sigma_sep.item():.4f}"
        )
        print(
            f"log_sigma_spk  : {self.log_sigma_spk.item():.4f}"
        )
        print(
            f"log_sigma_conf : {self.log_sigma_conf.item():.4f}"
        )

        return {

            "total_loss": total,

            "separation_loss": sep,

            "speaker_loss": spk,

            "confidence_loss": conf,

            "log_sigma_sep": self.log_sigma_sep.detach(),

            "log_sigma_spk": self.log_sigma_spk.detach(),
            
            "log_sigma_conf": self.log_sigma_conf.detach(),

        }

# ==========================================================
# Optimizer
# ==========================================================

criterion = EnhancedMossFormerLoss().to(DEVICE)
print(next(criterion.parameters()).device)

optimizer = optim.AdamW(

    [
        {
            "params": model.parameters(),
        },
        {
            "params": criterion.parameters(),
        },
    ],

    lr=1e-4,

    weight_decay=1e-5,

)

scheduler = optim.lr_scheduler.CosineAnnealingLR(

    optimizer,

    T_max=20,

)

scaler = torch.amp.GradScaler("cuda")

print("Optimizer Ready")

# ==========================================================
# Dataset
# ==========================================================

class MossFormerDataset(Dataset):

    def __init__(

        self,

        root_dir,

    ):

        self.mixtures = sorted(

            glob.glob(

                os.path.join(

                    root_dir,

                    "*_mix.wav",

                )

            )

        )

    def __len__(self):

        return len(self.mixtures)

    def __getitem__(

        self,

        idx,

    ):

        mix_path = self.mixtures[idx]

        mixture, _ = torchaudio.load(

            mix_path

        )

        src1, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source1.wav",

            )

        )

        src2, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source2.wav",

            )

        )

        src3, _ = torchaudio.load(

            mix_path.replace(

                "_mix.wav",

                "_source3.wav",

            )

        )

        length = mixture.shape[1]

        if length > CROP_SIZE:

            start = torch.randint(

                0,

                length - CROP_SIZE,

                (1,),

            ).item()

            end = start + CROP_SIZE

            mixture = mixture[:, start:end]

            src1 = src1[:, start:end]

            src2 = src2[:, start:end]

            src3 = src3[:, start:end]

        sources = torch.stack(

            [

                src1.squeeze(0),

                src2.squeeze(0),

                src3.squeeze(0),

            ],

            dim=-1,

        )

        return {

            "mixture": mixture,

            "sources": sources,

            "num_speakers": torch.tensor(

                3,

                dtype=torch.long,

            ),

            "confidence": torch.tensor(

                [

                    1.,

                    1.,

                    1.,

                    0.,

                    0.,

                    0.,

                    0.,

                    0.,

                ],

                dtype=torch.float32,

            ),

        }

# ==========================================================
# DataLoader
# ==========================================================

def collate_fn(batch):

    mixtures = [

        x["mixture"].squeeze()

        for x in batch

    ]

    mixtures = pad_sequence(

        mixtures,

        batch_first=True,

    )

    sources = [

        x["sources"]

        for x in batch

    ]

    max_len = max(

        s.shape[0]

        for s in sources

    )

    padded = []

    for s in sources:

        if s.shape[0] < max_len:

            s = torch.cat(

                [

                    s,

                    torch.zeros(

                        max_len - s.shape[0],

                        3,

                    ),

                ],

                dim=0,

            )

        padded.append(s)

    return {

        "mixture": mixtures,

        "sources": torch.stack(padded),

        "num_speakers": torch.stack(

            [

                x["num_speakers"]

                for x in batch

            ]

        ),

        "confidence": torch.stack(

            [

                x["confidence"]

                for x in batch

            ]

        ),

    }

train_dataset = MossFormerDataset(

    "MossFormer2_samples_WSJ0-3mix"

)

train_loader = DataLoader(

    train_dataset,

    batch_size=1,

    shuffle=True,

    collate_fn=collate_fn,

)

print(len(train_dataset))
print(len(train_loader))

# ==========================================================
# Train One Epoch
# ==========================================================

def train_one_epoch(

    model,

    dataloader,

    optimizer,

    criterion,

    scaler,

    scheduler=None,

):

    model.train()

    running_loss = 0.0
    running_sep = 0.0
    running_spk = 0.0
    running_conf = 0.0

    progress = tqdm(
        dataloader,
        desc="Training",
    )

    for batch in progress:

        mixture = batch["mixture"].to(
            DEVICE,
            non_blocking=True,
        )

        sources = batch["sources"].to(
            DEVICE,
            non_blocking=True,
        )

        num_speakers = batch["num_speakers"].to(
            DEVICE,
            non_blocking=True,
        )

        confidence = batch["confidence"].to(
            DEVICE,
            non_blocking=True,
        )

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(

            device_type="cuda",

            enabled=False #torch.cuda.is_available(),

        ):

            outputs = model(mixture)

            losses = criterion(

                outputs,

                sources,

                num_speakers,

                confidence,

            )

            if torch.isnan(losses["separation_loss"]):
                print("NaN separation loss detected")
                break
            if torch.isnan(outputs["audio"]).any():
                print("NaN in separated audio")
                
            print("\n========== Forward Check ==========")

            for name, tensor in outputs.items():

                print(

                    name,

                    "NaN:", torch.isnan(tensor).any().item(),

                    "Inf:", torch.isinf(tensor).any().item(),

                )

            print("Total Loss :", losses["total_loss"].item())
            print("Sep Loss   :", losses["separation_loss"].item())
            print("Spk Loss   :", losses["speaker_loss"].item())
            print("Conf Loss  :", losses["confidence_loss"].item())

        scaler.scale(
            losses["total_loss"]
        ).backward()

        print("\n========== Gradient Check ==========")

        for name, param in model.named_parameters():

            if param.grad is None:
                continue

            if torch.isnan(param.grad).any():

                print(f"NaN Gradient : {name}")

                break

            if torch.isinf(param.grad).any():

                print(f"Inf Gradient : {name}")

                break

        scaler.unscale_(optimizer)

        torch.nn.utils.clip_grad_norm_(

            model.parameters(),

            max_norm=1.0,

        )

        scaler.step(optimizer)

        scaler.update()

        for name, param in model.named_parameters():

            if torch.isnan(param).any():

                print(f"NaN weights in {name}")

                raise RuntimeError("NaN weights detected")

        running_loss += losses["total_loss"].item()
        running_sep += losses["separation_loss"].item()
        running_spk += losses["speaker_loss"].item()
        running_conf += losses["confidence_loss"].item()

        progress.set_postfix(

            Loss=f"{running_loss/(progress.n+1):.4f}",

            Sep=f"{running_sep/(progress.n+1):.4f}",

            Spk=f"{running_spk/(progress.n+1):.4f}",

            Conf=f"{running_conf/(progress.n+1):.4f}",

        )

    if scheduler is not None:

        scheduler.step()

    return {

        "loss": running_loss / len(dataloader),

        "separation_loss": running_sep / len(dataloader),

        "speaker_loss": running_spk / len(dataloader),

        "confidence_loss": running_conf / len(dataloader),

    }

# ==========================================================
# Validation
# ==========================================================

@torch.no_grad()
def validate(

    model,

    dataloader,

    criterion,

):

    model.eval()

    running = 0.0
    running_sisdr = 0.0

    for batch in dataloader:

        mixture = batch["mixture"].to(DEVICE)

        target_audio = batch["sources"].to(DEVICE)

        target_num_speakers = batch["num_speakers"].to(DEVICE)

        target_confidence = batch["confidence"].to(DEVICE)

        outputs = model(mixture)

        losses = criterion(

            outputs,

            target_audio,

            target_num_speakers,

            target_confidence,

        )

        score = sisdr(

            outputs["audio"].permute(0, 2, 1),

            target_audio.permute(0, 2, 1),

        )

        running += losses["total_loss"].item()

        running_sisdr += score.item()

    return {

        "loss": running / len(dataloader),

        "sisdr": running_sisdr / len(dataloader),

    }

# ==========================================================
# Train
# ==========================================================

gc.collect()

torch.cuda.empty_cache()

best_loss = float("inf")

NUM_EPOCHS = 20

for epoch in range(NUM_EPOCHS):

    print("\n" + "=" * 60)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
    print("=" * 60)

    history = train_one_epoch(

        model=model,

        dataloader=train_loader,

        optimizer=optimizer,

        criterion=criterion,

        scaler=scaler,

        scheduler=scheduler,

    )

    metrics = validate(

        model,

        train_loader,

        criterion,

    )

    print("\nTraining")

    for key, value in history.items():

        print(f"{key:20}: {value:.5f}")

    print("\nValidation")

    print(f"Loss               : {metrics['loss']:.5f}")

    print(f"SI-SDR             : {metrics['sisdr']:.5f}")

    if metrics["loss"] < best_loss:

        best_loss = metrics["loss"]

        torch.save(

            {

                "model": model.state_dict(),

                "optimizer": optimizer.state_dict(),

                "epoch": epoch,

                "loss": metrics["loss"],

            },

            "best_enhanced_mossformer.pth",

        )

        print("\n✓ Best model saved.")

# ==========================================================
# Block 17
# Inference using Best Model + Save WAV Files
# ==========================================================

import os
import torch
import torchaudio
from tqdm import tqdm

SAVE_DIR = "/kaggle/working/separated_audio"

os.makedirs(
    SAVE_DIR,
    exist_ok=True,
)

# ----------------------------------------------------------
# Load Best Checkpoint
# ----------------------------------------------------------

checkpoint = torch.load(
    "best_enhanced_mossformer.pth",
    map_location=DEVICE,
)

model.load_state_dict(checkpoint["model"])

model.to(DEVICE)
model.eval()

print(f"Loaded best model from epoch {checkpoint['epoch'] + 1}")

# ----------------------------------------------------------
# Run inference on all mixtures
# ----------------------------------------------------------

mix_files = train_dataset.mixtures      # Use val_dataset.mixtures if preferred

with torch.no_grad():

    for mix_path in tqdm(mix_files):

        mixture, sr = torchaudio.load(mix_path)

        mixture = mixture.to(DEVICE)

        outputs = model(mixture)

        separated = outputs["audio"].cpu()

        sample_name = os.path.basename(
            mix_path
        ).replace("_mix.wav", "")

        sample_dir = os.path.join(
            SAVE_DIR,
            sample_name,
        )

        os.makedirs(
            sample_dir,
            exist_ok=True,
        )

        # --------------------------------------------------
        # Save mixture
        # --------------------------------------------------

        torchaudio.save(
            os.path.join(
                sample_dir,
                "mixture.wav",
            ),
            mixture.cpu(),
            sr,
        )

        # --------------------------------------------------
        # Save predicted speakers
        # --------------------------------------------------

        for spk in range(separated.shape[-1]):

            torchaudio.save(

                os.path.join(
                    sample_dir,
                    f"pred_speaker_{spk+1}.wav",
                ),

                separated[:, :, spk],

                sr,

            )

        # --------------------------------------------------
        # Save ground-truth speakers (optional)
        # --------------------------------------------------

        for spk in range(1, 4):

            gt_path = mix_path.replace(
                "_mix.wav",
                f"_source{spk}.wav",
            )

            if os.path.exists(gt_path):

                gt_audio, _ = torchaudio.load(gt_path)

                torchaudio.save(

                    os.path.join(
                        sample_dir,
                        f"gt_speaker_{spk}.wav",
                    ),

                    gt_audio,

                    sr,

                )

print("\n All audio files have been saved.")

print(f"\nSaved to:\n{SAVE_DIR}")
# Out:
# mossformer2-wsj0mix-3spk config loaded
# model initialised on cuda:0
# Waveform : torch.Size([1, 44920])
# Encoder  : torch.Size([1, 512, 5614])
# mossformer2-wsj0mix-3spk config loaded
# model initialised on cuda:0
# ============================================================
# torch.Size([1, 44920, 3])
# torch.Size([1, 8])
# torch.Size([1, 8])
# ============================================================
# Total : 57056002
# Trainable : 57039618
# cuda:0
# Optimizer Ready
# 38
# 38
#
# ============================================================
# Epoch 1/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : 0.0000
# log_sigma_spk  : 0.0000
# log_sigma_conf : 0.0000
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.1681313514709473
# Sep Loss   : 0.40434399247169495
# Spk Loss   : 2.0659263134002686
# Conf Loss  : 0.6978610157966614
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0001
# log_sigma_spk  : 0.0001
# log_sigma_conf : -0.0001
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.204319477081299
# Sep Loss   : 0.41943415999412537
# Spk Loss   : 2.0890731811523438
# Conf Loss  : 0.6960093975067139
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0002
# log_sigma_spk  : 0.0002
# log_sigma_conf : -0.0002
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.4521484375
# Sep Loss   : 0.6902779936790466
# Spk Loss   : 2.064873456954956
# Conf Loss  : 0.6973322629928589
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0003
# log_sigma_spk  : 0.0003
# log_sigma_conf : -0.0003
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0533037185668945
# Sep Loss   : 0.2940991222858429
# Spk Loss   : 2.065361261367798
# Conf Loss  : 0.6944624185562134
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0004
# log_sigma_spk  : 0.0004
# log_sigma_conf : -0.0004
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.503289222717285
# Sep Loss   : 0.7884417772293091
# Spk Loss   : 2.0341079235076904
# Conf Loss  : 0.6813632249832153
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0005
# log_sigma_spk  : 0.0005
# log_sigma_conf : -0.0005
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.05702543258667
# Sep Loss   : 0.31396615505218506
# Spk Loss   : 2.0557496547698975
# Conf Loss  : 0.6883232593536377
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0006
# log_sigma_spk  : 0.0006
# log_sigma_conf : -0.0006
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.1558239459991455
# Sep Loss   : 0.4536954164505005
# Spk Loss   : 2.0193490982055664
# Conf Loss  : 0.6838942766189575
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0007
# log_sigma_spk  : 0.0007
# log_sigma_conf : -0.0007
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.05551815032959
# Sep Loss   : 0.33601078391075134
# Spk Loss   : 2.0343434810638428
# Conf Loss  : 0.6865514516830444
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0008
# log_sigma_spk  : 0.0008
# log_sigma_conf : -0.0008
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.095672607421875
# Sep Loss   : 0.42127230763435364
# Spk Loss   : 1.9908442497253418
# Conf Loss  : 0.6850431561470032
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0009
# log_sigma_spk  : 0.0009
# log_sigma_conf : -0.0009
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9239745140075684
# Sep Loss   : 0.19272646307945251
# Spk Loss   : 2.046302080154419
# Conf Loss  : 0.6868647336959839
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0010
# log_sigma_spk  : 0.0010
# log_sigma_conf : -0.0010
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.001984119415283
# Sep Loss   : 0.3078717291355133
# Spk Loss   : 2.010512590408325
# Conf Loss  : 0.6855885982513428
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0011
# log_sigma_spk  : 0.0011
# log_sigma_conf : -0.0011
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.0279150009155273
# Sep Loss   : 0.3523510992527008
# Spk Loss   : 1.9974764585494995
# Conf Loss  : 0.6802212595939636
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0012
# log_sigma_spk  : 0.0012
# log_sigma_conf : -0.0012
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.107698917388916
# Sep Loss   : 0.4561947286128998
# Spk Loss   : 1.9876073598861694
# Conf Loss  : 0.6661109328269958
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0013
# log_sigma_spk  : 0.0013
# log_sigma_conf : -0.0013
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8809242248535156
# Sep Loss   : 0.20027276873588562
# Spk Loss   : 1.9978867769241333
# Conf Loss  : 0.6854755282402039
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0014
# log_sigma_spk  : 0.0014
# log_sigma_conf : -0.0014
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 3.046982765197754
# Sep Loss   : 0.4365576505661011
# Spk Loss   : 1.9477466344833374
# Conf Loss  : 0.6652360558509827
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0015
# log_sigma_spk  : 0.0015
# log_sigma_conf : -0.0015
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9771738052368164
# Sep Loss   : 0.337555468082428
# Spk Loss   : 1.9783157110214233
# Conf Loss  : 0.6642359495162964
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0016
# log_sigma_spk  : 0.0016
# log_sigma_conf : -0.0016
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9523401260375977
# Sep Loss   : 0.31737270951271057
# Spk Loss   : 1.968581199645996
# Conf Loss  : 0.6695238351821899
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0017
# log_sigma_spk  : 0.0017
# log_sigma_conf : -0.0017
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9416866302490234
# Sep Loss   : 0.3049437701702118
# Spk Loss   : 1.968929409980774
# Conf Loss  : 0.671167254447937
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0018
# log_sigma_spk  : 0.0018
# log_sigma_conf : -0.0018
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.897944450378418
# Sep Loss   : 0.2908220589160919
# Spk Loss   : 1.942327857017517
# Conf Loss  : 0.6683293581008911
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0019
# log_sigma_spk  : 0.0019
# log_sigma_conf : -0.0019
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.925117254257202
# Sep Loss   : 0.33225467801094055
# Spk Loss   : 1.935626745223999
# Conf Loss  : 0.660892903804779
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0020
# log_sigma_spk  : 0.0020
# log_sigma_conf : -0.0020
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.9542579650878906
# Sep Loss   : 0.3671859800815582
# Spk Loss   : 1.9352072477340698
# Conf Loss  : 0.6556561589241028
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0021
# log_sigma_spk  : 0.0021
# log_sigma_conf : -0.0021
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.826145887374878
# Sep Loss   : 0.2233678698539734
# Spk Loss   : 1.9399243593215942
# Conf Loss  : 0.6671196818351746
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0022
# log_sigma_spk  : 0.0022
# log_sigma_conf : -0.0022
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.83024001121521
# Sep Loss   : 0.1947157233953476
# Spk Loss   : 1.9697837829589844
# Conf Loss  : 0.6703318953514099
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0023
# log_sigma_spk  : 0.0023
# log_sigma_conf : -0.0023
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8104686737060547
# Sep Loss   : 0.24082987010478973
# Spk Loss   : 1.9098615646362305
# Conf Loss  : 0.6643520593643188
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0024
# log_sigma_spk  : 0.0024
# log_sigma_conf : -0.0024
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.8133864402770996
# Sep Loss   : 0.18217578530311584
# Spk Loss   : 1.9663509130477905
# Conf Loss  : 0.6698967218399048
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0025
# log_sigma_spk  : 0.0025
# log_sigma_conf : -0.0025
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.785473346710205
# Sep Loss   : 0.3763786554336548
# Spk Loss   : 1.7845685482025146
# Conf Loss  : 0.6289464235305786
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0026
# log_sigma_spk  : 0.0026
# log_sigma_conf : -0.0026
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.789339303970337
# Sep Loss   : 0.30384260416030884
# Spk Loss   : 1.8433507680892944
# Conf Loss  : 0.6470359563827515
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0027
# log_sigma_spk  : 0.0027
# log_sigma_conf : -0.0027
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.728961229324341
# Sep Loss   : 0.2575492858886719
# Spk Loss   : 1.8319180011749268
# Conf Loss  : 0.6446744203567505
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0028
# log_sigma_spk  : 0.0028
# log_sigma_conf : -0.0028
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.718428611755371
# Sep Loss   : 0.18755760788917542
# Spk Loss   : 1.884987711906433
# Conf Loss  : 0.6515791416168213
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0029
# log_sigma_spk  : 0.0028
# log_sigma_conf : -0.0029
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.6992316246032715
# Sep Loss   : 0.2546064853668213
# Spk Loss   : 1.8076097965240479
# Conf Loss  : 0.642527163028717
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0030
# log_sigma_spk  : 0.0029
# log_sigma_conf : -0.0030
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.666342258453369
# Sep Loss   : 0.14895866811275482
# Spk Loss   : 1.8735929727554321
# Conf Loss  : 0.6499840021133423
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0031
# log_sigma_spk  : 0.0030
# log_sigma_conf : -0.0031
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.650757074356079
# Sep Loss   : 0.1272013932466507
# Spk Loss   : 1.8725636005401611
# Conf Loss  : 0.657435417175293
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0032
# log_sigma_spk  : 0.0031
# log_sigma_conf : -0.0032
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.612016439437866
# Sep Loss   : 0.17542552947998047
# Spk Loss   : 1.8017268180847168
# Conf Loss  : 0.6411930322647095
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0033
# log_sigma_spk  : 0.0032
# log_sigma_conf : -0.0033
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.601562738418579
# Sep Loss   : 0.1259078085422516
# Spk Loss   : 1.8411095142364502
# Conf Loss  : 0.6413670778274536
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0035
# log_sigma_spk  : 0.0033
# log_sigma_conf : -0.0035
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.569711208343506
# Sep Loss   : 0.15074671804904938
# Spk Loss   : 1.7867567539215088
# Conf Loss  : 0.6389815807342529
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0036
# log_sigma_spk  : 0.0034
# log_sigma_conf : -0.0036
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.563659191131592
# Sep Loss   : 0.12876194715499878
# Spk Loss   : 1.8030320405960083
# Conf Loss  : 0.6389754414558411
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0037
# log_sigma_spk  : 0.0035
# log_sigma_conf : -0.0037
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.518463134765625
# Sep Loss   : 0.20723721385002136
# Spk Loss   : 1.7084569931030273
# Conf Loss  : 0.6095746159553528
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0038
# log_sigma_spk  : 0.0036
# log_sigma_conf : -0.0038
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.5458710193634033
# Sep Loss   : 0.07634472846984863
# Spk Loss   : 1.8353594541549683
# Conf Loss  : 0.6419926881790161
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
#
# Training
# loss                : 2.89772
# separation_loss     : 0.29945
# speaker_loss        : 1.93677
# confidence_loss     : 0.66516
#
# Validation
# Loss               : 2.47862
# SI-SDR             : -4.46632
#
# ✓ Best model saved.
#
# ============================================================
# Epoch 2/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0039
# log_sigma_spk  : 0.0037
# log_sigma_conf : -0.0039
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.4597721099853516
# Sep Loss   : 0.13844066858291626
# Spk Loss   : 1.7067065238952637
# Conf Loss  : 0.6220283508300781
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0040
# log_sigma_spk  : 0.0038
# log_sigma_conf : -0.0040
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3722376823425293
# Sep Loss   : 0.09224247187376022
# Spk Loss   : 1.6671106815338135
# Conf Loss  : 0.620527982711792
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0041
# log_sigma_spk  : 0.0039
# log_sigma_conf : -0.0041
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.416904926300049
# Sep Loss   : 0.1199808269739151
# Spk Loss   : 1.6936535835266113
# Conf Loss  : 0.6111383438110352
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0042
# log_sigma_spk  : 0.0039
# log_sigma_conf : -0.0042
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3553388118743896
# Sep Loss   : 0.08888102322816849
# Spk Loss   : 1.6590427160263062
# Conf Loss  : 0.6154590845108032
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0043
# log_sigma_spk  : 0.0040
# log_sigma_conf : -0.0043
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.2542884349823
# Sep Loss   : 0.096588134765625
# Spk Loss   : 1.5769106149673462
# Conf Loss  : 0.5887837409973145
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0045
# log_sigma_spk  : 0.0041
# log_sigma_conf : -0.0044
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3460512161254883
# Sep Loss   : 0.06652388721704483
# Spk Loss   : 1.6728768348693848
# Conf Loss  : 0.6152483224868774
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0046
# log_sigma_spk  : 0.0042
# log_sigma_conf : -0.0045
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.3338749408721924
# Sep Loss   : 0.05716158077120781
# Spk Loss   : 1.6748334169387817
# Conf Loss  : 0.6107509136199951
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0047
# log_sigma_spk  : 0.0043
# log_sigma_conf : -0.0046
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.2934865951538086
# Sep Loss   : 0.05902574583888054
# Spk Loss   : 1.642432451248169
# Conf Loss  : 0.6010011434555054
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0048
# log_sigma_spk  : 0.0044
# log_sigma_conf : -0.0047
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.274515390396118
# Sep Loss   : 0.05602746456861496
# Spk Loss   : 1.6315809488296509
# Conf Loss  : 0.596072256565094
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0049
# log_sigma_spk  : 0.0044
# log_sigma_conf : -0.0048
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.120187759399414
# Sep Loss   : 0.059895385056734085
# Spk Loss   : 1.4873912334442139
# Conf Loss  : 0.5816805958747864
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0050
# log_sigma_spk  : 0.0045
# log_sigma_conf : -0.0049
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.0360467433929443
# Sep Loss   : 0.06691320985555649
# Spk Loss   : 1.4280688762664795
# Conf Loss  : 0.5498896837234497
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0051
# log_sigma_spk  : 0.0046
# log_sigma_conf : -0.0050
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.188361883163452
# Sep Loss   : 0.04179888218641281
# Spk Loss   : 1.5664138793945312
# Conf Loss  : 0.5897238850593567
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0053
# log_sigma_spk  : 0.0047
# log_sigma_conf : -0.0052
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.219710350036621
# Sep Loss   : 0.04335283488035202
# Spk Loss   : 1.582034945487976
# Conf Loss  : 0.6040847301483154
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0054
# log_sigma_spk  : 0.0047
# log_sigma_conf : -0.0053
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.2098913192749023
# Sep Loss   : 0.03745872899889946
# Spk Loss   : 1.5766639709472656
# Conf Loss  : 0.6057244539260864
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0055
# log_sigma_spk  : 0.0048
# log_sigma_conf : -0.0054
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.246373414993286
# Sep Loss   : 0.036259543150663376
# Spk Loss   : 1.6348884105682373
# Conf Loss  : 0.5857715606689453
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0056
# log_sigma_spk  : 0.0049
# log_sigma_conf : -0.0055
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.2851576805114746
# Sep Loss   : 0.03406546637415886
# Spk Loss   : 1.6491440534591675
# Conf Loss  : 0.6126313209533691
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0057
# log_sigma_spk  : 0.0050
# log_sigma_conf : -0.0056
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.0280749797821045
# Sep Loss   : 0.038283806294202805
# Spk Loss   : 1.441022515296936
# Conf Loss  : 0.5589004755020142
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0058
# log_sigma_spk  : 0.0050
# log_sigma_conf : -0.0057
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.9296576976776123
# Sep Loss   : 0.04351171478629112
# Spk Loss   : 1.354358196258545
# Conf Loss  : 0.5417430400848389
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0060
# log_sigma_spk  : 0.0051
# log_sigma_conf : -0.0058
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8996202945709229
# Sep Loss   : 0.05420089513063431
# Spk Loss   : 1.3300138711929321
# Conf Loss  : 0.5254538655281067
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0061
# log_sigma_spk  : 0.0052
# log_sigma_conf : -0.0059
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8750050067901611
# Sep Loss   : 0.040767621248960495
# Spk Loss   : 1.3097022771835327
# Conf Loss  : 0.53468918800354
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0062
# log_sigma_spk  : 0.0052
# log_sigma_conf : -0.0060
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8389391899108887
# Sep Loss   : 0.04500167816877365
# Spk Loss   : 1.2848564386367798
# Conf Loss  : 0.519355058670044
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0063
# log_sigma_spk  : 0.0053
# log_sigma_conf : -0.0062
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 2.139045238494873
# Sep Loss   : 0.026694219559431076
# Spk Loss   : 1.5345617532730103
# Conf Loss  : 0.5892494320869446
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0064
# log_sigma_spk  : 0.0054
# log_sigma_conf : -0.0063
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.8424944877624512
# Sep Loss   : 0.035963110625743866
# Spk Loss   : 1.296321153640747
# Conf Loss  : 0.520957350730896
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0065
# log_sigma_spk  : 0.0054
# log_sigma_conf : -0.0064
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7024831771850586
# Sep Loss   : 0.0365494079887867
# Spk Loss   : 1.1795717477798462
# Conf Loss  : 0.4968116879463196
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0066
# log_sigma_spk  : 0.0055
# log_sigma_conf : -0.0065
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.69753098487854
# Sep Loss   : 0.03260786458849907
# Spk Loss   : 1.1688505411148071
# Conf Loss  : 0.5066048502922058
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0068
# log_sigma_spk  : 0.0055
# log_sigma_conf : -0.0066
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7458417415618896
# Sep Loss   : 0.03488227352499962
# Spk Loss   : 1.2187294960021973
# Conf Loss  : 0.5032216906547546
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0069
# log_sigma_spk  : 0.0056
# log_sigma_conf : -0.0067
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7109153270721436
# Sep Loss   : 0.035700272768735886
# Spk Loss   : 1.1730728149414062
# Conf Loss  : 0.5129878520965576
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0070
# log_sigma_spk  : 0.0056
# log_sigma_conf : -0.0069
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7925766706466675
# Sep Loss   : 0.03259054198861122
# Spk Loss   : 1.2489163875579834
# Conf Loss  : 0.522473931312561
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0071
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0070
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.5607874393463135
# Sep Loss   : 0.03167928010225296
# Spk Loss   : 1.0511332750320435
# Conf Loss  : 0.48868006467819214
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0072
# log_sigma_spk  : 0.0057
# log_sigma_conf : -0.0071
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.4666451215744019
# Sep Loss   : 0.04258964583277702
# Spk Loss   : 0.9911179542541504
# Conf Loss  : 0.4437142610549927
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0073
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0072
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.4983571767807007
# Sep Loss   : 0.0381903275847435
# Spk Loss   : 0.9974230527877808
# Conf Loss  : 0.4735487997531891
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0074
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0073
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.5418400764465332
# Sep Loss   : 0.02948802150785923
# Spk Loss   : 1.0528335571289062
# Conf Loss  : 0.4709012508392334
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0076
# log_sigma_spk  : 0.0058
# log_sigma_conf : -0.0075
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.7619638442993164
# Sep Loss   : 0.024134093895554543
# Spk Loss   : 1.2281042337417603
# Conf Loss  : 0.5219622850418091
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0077
# log_sigma_spk  : 0.0059
# log_sigma_conf : -0.0076
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.5397480726242065
# Sep Loss   : 0.03593562915921211
# Spk Loss   : 1.0204845666885376
# Conf Loss  : 0.49464350938796997
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0078
# log_sigma_spk  : 0.0059
# log_sigma_conf : -0.0077
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.4909868240356445
# Sep Loss   : 0.031910091638565063
# Spk Loss   : 1.009708046913147
# Conf Loss  : 0.4610828459262848
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0079
# log_sigma_spk  : 0.0059
# log_sigma_conf : -0.0078
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.3506816625595093
# Sep Loss   : 0.03716073930263519
# Spk Loss   : 0.9042037725448608
# Conf Loss  : 0.42085790634155273
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0080
# log_sigma_spk  : 0.0059
# log_sigma_conf : -0.0079
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.46116042137146
# Sep Loss   : 0.0273352712392807
# Spk Loss   : 1.0002832412719727
# Conf Loss  : 0.44571077823638916
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0081
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0081
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.410154104232788
# Sep Loss   : 0.03952838480472565
# Spk Loss   : 0.944918155670166
# Conf Loss  : 0.43769121170043945
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
#
# Training
# loss                : 1.93939
# separation_loss     : 0.04972
# speaker_loss        : 1.35763
# confidence_loss     : 0.54215
#
# Validation
# Loss               : 1.32871
# SI-SDR             : -14.93217
#
# ✓ Best model saved.
#
# ============================================================
# Epoch 3/20
# ============================================================
# Training:   0%|          | 0/38 [00:00<?, ?it/s]
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0082
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0082
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.197074055671692
# Sep Loss   : 0.039257679134607315
# Spk Loss   : 0.7788291573524475
# Conf Loss  : 0.39054715633392334
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0084
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0083
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.2483370304107666
# Sep Loss   : 0.030811727046966553
# Spk Loss   : 0.8096098899841309
# Conf Loss  : 0.41966575384140015
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0085
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0084
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : 1.29172945022583
# Sep Loss   : 0.034334734082221985
# Spk Loss   : 0.838902473449707
# Conf Loss  : 0.4304736852645874
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0086
# log_sigma_spk  : 0.0060
# log_sigma_conf : -0.0086
# ...
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.07445637881755829
# Sep Loss   : 0.012584752403199673
# Spk Loss   : 0.01844082586467266
# Conf Loss  : 0.012082265689969063
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09546871483325958
# Sep Loss   : 0.014630656689405441
# Spk Loss   : 0.003948868252336979
# Conf Loss  : 0.004239893052726984
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09349323809146881
# Sep Loss   : 0.021949071437120438
# Spk Loss   : 0.001211386057548225
# Conf Loss  : 0.0015355159994214773
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09983249753713608
# Sep Loss   : 0.013816230930387974
# Spk Loss   : 0.0015016243560239673
# Conf Loss  : 0.003294519614428282
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09716726094484329
# Sep Loss   : 0.014216633513569832
# Spk Loss   : 0.002055676421150565
# Conf Loss  : 0.004894270561635494
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09862996637821198
# Sep Loss   : 0.01494836900383234
# Spk Loss   : 0.0024845702573657036
# Conf Loss  : 0.002355399075895548
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09736037999391556
# Sep Loss   : 0.016613591462373734
# Spk Loss   : 0.0020452074240893126
# Conf Loss  : 0.002342761028558016
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0873454287648201
# Sep Loss   : 0.02554391697049141
# Spk Loss   : 0.0011994794476777315
# Conf Loss  : 0.003840782679617405
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09745851159095764
# Sep Loss   : 0.01419203169643879
# Spk Loss   : 0.0025253568310290575
# Conf Loss  : 0.004188165999948978
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09943066537380219
# Sep Loss   : 0.015828026458621025
# Spk Loss   : 0.0012369846226647496
# Conf Loss  : 0.0019487709505483508
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09296576678752899
# Sep Loss   : 0.020468568429350853
# Spk Loss   : 0.0006381620769388974
# Conf Loss  : 0.004085156135261059
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0948122963309288
# Sep Loss   : 0.015963638201355934
# Spk Loss   : 0.003504684194922447
# Conf Loss  : 0.003994247876107693
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09501124173402786
# Sep Loss   : 0.01791059970855713
# Spk Loss   : 0.0023254514671862125
# Conf Loss  : 0.0030279953498393297
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09159895777702332
# Sep Loss   : 0.02391257882118225
# Spk Loss   : 0.0010109796421602368
# Conf Loss  : 0.0016054051229730248
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.08958732336759567
# Sep Loss   : 0.014349869452416897
# Spk Loss   : 0.0055300588719546795
# Conf Loss  : 0.008594916202127934
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0926198810338974
# Sep Loss   : 0.02096579410135746
# Spk Loss   : 0.0017708349041640759
# Conf Loss  : 0.0028194894548505545
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09466618299484253
# Sep Loss   : 0.012643505819141865
# Spk Loss   : 0.005694832187145948
# Conf Loss  : 0.005294472444802523
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0981132984161377
# Sep Loss   : 0.018560275435447693
# Spk Loss   : 0.0003618539194576442
# Conf Loss  : 0.0013612781185656786
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09664871543645859
# Sep Loss   : 0.017153937369585037
# Spk Loss   : 0.0011731653939932585
# Conf Loss  : 0.0033602118492126465
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.0867682695388794
# Sep Loss   : 0.02797628752887249
# Spk Loss   : 0.0011301804333925247
# Conf Loss  : 0.002063471358269453
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09735625237226486
# Sep Loss   : 0.015481061302125454
# Spk Loss   : 0.0023981165140867233
# Conf Loss  : 0.0031512982677668333
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# ========== Forward Check ==========
# audio NaN: False Inf: False
# speaker_logits NaN: False Inf: False
# confidence NaN: False Inf: False
# Total Loss : -0.09557239711284637
# Sep Loss   : 0.018744247034192085
# Spk Loss   : 0.0013341344892978668
# Conf Loss  : 0.0026530916802585125
#
# ========== Gradient Check ==========
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
# audio NaN : False
# target NaN: False
# audio Inf : False
# target Inf: False
# log_sigma_sep  : -0.0421
# log_sigma_spk  : -0.0285
# log_sigma_conf : -0.0486
#
# Training
# loss                : -0.09363
# separation_loss     : 0.01714
# speaker_loss        : 0.00324
# confidence_loss     : 0.00420
#
# Validation
# Loss               : -0.09606
# SI-SDR             : 5.70776
#
# ✓ Best model saved.
# Loaded best model from epoch 20
# 100%|██████████| 38/38 [00:32<00:00,  1.16it/s]
#  All audio files have been saved.
#
# Saved to:
# /kaggle/working/separated_audio
